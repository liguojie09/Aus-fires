# %% [markdown]
# # PART A.  MongoDB Data Model
# ---

# %% [markdown]
# ### 'climate_record' collection example

# %%
{
    "_id": ObjectId("BBB"),
    "station": "31234"
    "date" : ISODate("2017-01-20T00:00:00Z"),
    "air_temperature_celcius" : 16,
    "relative_humidity" : 50.9,
    "windspeed_knots" : 12.9,
    "max_wind_speed" : 21,
    "precipitation" : " 0.03G"
}

# %% [markdown]
# ### 'hotspot_record' collection example

# %%
{
    "_id" : ObjectId("EEE"),
    "latitude" : -38.048,
    "longitude" : 144.213,
    "datetime" : ISODate("2017-12-16T00:21:11Z"),
    "confidence" : 82,
    "date" : ISODate("2017-12-16T00:00:00Z"),
    "surface_temperature_celcius" : 55
}

# %% [markdown]
# ### Justification

# %% [markdown]
# As shown in the examples above, two collections, climate_record and hotspot_record are created to model the data structure presented in the given files. The reasons are listed below:
#
# 1. There is a *one-to-many* relationship between *climate* and *hotspot*. Though mongodb prefers nested table over referencing to handle *one-to-many* relationship, it isn't practical to employ nested table in this case as there is no guarantee that climate record will always be generated before hotspot record in the live streaming. If the order of record generation is against the design, it will not be possible to store hotspot records into the system. As such, it is safer to leave the relationship as it is and rely on parent referencing to map these two tables together.
#
# 2. *station* in *climate* can be extracted out to a *Station* collection in order to achieve a 'normalized' design and hence facilitate CRUD operations on the database. In live streaming, however, in most cases there will be no updates operations. Forthermore, seperating *Station* from *Climate* imposes more processing power and time, while the rate of data processing outweight the data integrity in data streaming. As such, extracting *Station* is considered unnecessary in this scenario.

# %% [markdown]
# # PART B
# ---

# %% [markdown]
# ### Hotspot table setup methods

# %%
import pymongo
import datetime


def get_hotspot_record(header, data_row):
    """
    Construct the record to insert to mongodb

    Args:
        header: A list of field names that denote the attributes of the record.
        data_row: A list of data.

    Returns:
        Record to insert

    """
    if len(header) != len(data_row):
        raise ValueError('Data might be corrupted -> header length does not match record length')

    record = {}
    for index, attribute in enumerate(header):
        attribute = attribute.strip()
        if attribute == "latitude" or attribute == "longitude":
            record[attribute] = float(data_row[index])
        elif attribute == "confidence" or attribute == "surface_temperature_celcius":
            record[attribute] = int(data_row[index])
        elif attribute == "datetime":  # convert the type of "datetime" from string to datetime
            record[attribute] = datetime.datetime.strptime(data_row[index], '%Y-%m-%dT%H:%M:%S')
        elif attribute == "date":  # convert the type of "date" from string to datetime
            record[attribute] = datetime.datetime.strptime(data_row[index], '%d/%m/%Y')
        else:
            raise ValueError("Failed to catch all the data fields")

    return record


def re_init_hotspot_table(file_location):
    """
    Drop the current hostspot table from mongodb and initialized a new one from the given file

    Args:
        file_location: CSV file where the new table is derived from

    Returns:
        whether the re-initialization is successful
    """

    data_to_insert = []   # a list of hotspot records to insert to the database

    hotspot_file = open(file_location)

    file_as_list = hotspot_file.readlines()
    header = file_as_list[0].replace("\n", "").split(",")  # get a list of field name

    for index, raw_data in enumerate(file_as_list[1:]):  # loop all rows except for the header
        data_row = raw_data.replace("\n", "").split(",")
        data_to_insert.append(get_hotspot_record(header, data_row))

    ''' database connection '''
    connection = pymongo.MongoClient("localhost", 27017)
    database = connection["fit5148_assignment_db"]
    hotspot = database["hotspot_record"]

    hotspot.drop()  # remove current data

    hotspot.insert_many(data_to_insert)
    hotspot_file.close()
    return True

# %% [markdown]
# ### Climate and station table setup methods

# %%
import pymongo
import datetime

from bson import ObjectId

import pymongo
import datetime

from bson import ObjectId


def get_climate_record(header, data_row):
    """
    Construct the record to insert to mongodb

    Args:
        header: A list of field names that denote the attributes of the record.
        data_row: A list of data.

    Returns:
        Record to insert

    """
    if len(header) != len(data_row):
        raise ValueError('Data might be corrupted -> header length does not match record length')

    climate_record = {}
    for index, attribute in enumerate(header):
        attribute = attribute.strip()
        if attribute == "station" or attribute == "precipitation":
            climate_record[attribute] = str(data_row[index])
        elif attribute == "date":  # convert the type of "date" from string to datetime
            climate_record[attribute] = datetime.datetime.strptime(data_row[index], '%d/%m/%Y')
        elif attribute == "air_temperature_celcius":
            climate_record[attribute] = int(data_row[index])
        elif attribute == "relative_humidity" or attribute == "windspeed_knots" or attribute == "max_wind_speed":
            climate_record[attribute] = float(data_row[index])

        else:
            raise ValueError("Failed to catch all the data fields")

    return climate_record


def re_init_climate_table(file_location):
    """ Drop the current hostspot table from mongodb and initialized a new one from the given file

    Args:
        file_location: CSV file where the new table is derived from

    Returns:
        whether the re-initialization is successful
    """

    stations_dict = {}   # a dictionary of stations for fast station lookup
    climate_records = []

    climate_file = open(file_location)

    file_as_list = climate_file.readlines()
    header = file_as_list[0].replace("\n", "").split(",")  # get a list of field names

    for index, raw_data in enumerate(file_as_list[1:]):  # loop all rows except for the header
        data_row = raw_data.replace("\n", "").split(",")
        climate_record = get_climate_record(header, data_row)

        climate_records.append(climate_record)  # add records for climate table

    ''' database connection '''
    connection = pymongo.MongoClient("localhost", 27017)
    db = connection["fit5148_assignment_db"]

    ''' drop current tables'''
    db.climate.drop()

    ''' insert data to database'''
    db.climate.insert_many(climate_records)

    return True

# %% [markdown]
# ### Run the statements below to initialize the database
# ***Please make sure your mongodb is running and the correct paths are provided***

# %%
re_init_hotspot_table("/Users/frank/Desktop/Sem3/FIT5148/Assignment/data/hotspot_historic.csv")
re_init_climate_table("/Users/frank/Desktop/Sem3/FIT5148/Assignment/data/climate_historic.csv")
# Out:
# True

# %% [markdown]
# ### a
# Find climate data on 10th December 2017 .

# %%
import pymongo
import datetime,time
def question_a():
    connection = pymongo.MongoClient("localhost",27017) # connet database 
    database = connection["fit5148_assignment_db"] # connect climate database
    cli_collection = database["climate"]
    dateList = [] 
    # transfer the string to date to query 
    date = datetime.datetime.strptime("2017-12-10",'%Y-%m-%d')
    result = list(cli_collection.find({"date":date}))
    return result
    
question_a()
# Out:
# [{'_id': ObjectId('5ce737cc869a0fa6b08876d5'),
#   'station': '948702',
#   'date': datetime.datetime(2017, 12, 10, 0, 0),
#   'air_temperature_celcius': 17,
#   'relative_humidity': 53.5,
#   'windspeed_knots': 7.3,
#   'max_wind_speed': 14.0,
#   'precipitation': ' 0.00I'}]

# %% [markdown]
# ### b
# Find the latitude , longitude, surface temperature (°C) , and confidence when
# the surface temperature (°C) was between 65 °C and 100 °C .

# %%
import pymongo

def question_b():
    connection = pymongo.MongoClient("localhost", 27017)
    database = connection["fit5148_assignment_db"]
    hotspot = database["hotspot_record"]

    records = hotspot.find(
        {
            "$and": [
                {
                    "surface_temperature_celcius": {"$gte": 65}
                },
                {
                    "surface_temperature_celcius": {"$lte": 100}
                }
            ]
        },
        {
            "latitude": 1,
            "longitude": 1,
            "surface_temperature_celcius": 1,
            "confidence": 1
        }
    )

    for record in records:
        print(record)

    return records


question_b()
# Out:
# {'_id': ObjectId('5ce737cc869a0fa6b0886b11'), 'latitude': -37.966, 'longitude': 145.051, 'confidence': 78, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('5ce737cc869a0fa6b0886b14'), 'latitude': -35.543, 'longitude': 143.316, 'confidence': 86, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('5ce737cc869a0fa6b0886b1b'), 'latitude': -37.875, 'longitude': 142.51, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('5ce737cc869a0fa6b0886b1d'), 'latitude': -37.613, 'longitude': 149.305, 'confidence': 95, 'surface_temperature_celcius': 75}
# {'_id': ObjectId('5ce737cc869a0fa6b0886b1f'), 'latitude': -37.624, 'longitude': 149.314, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('5ce737cc869a0fa6b0886b22'), 'latitude': -38.057, 'longitude': 144.211, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('5ce737cc869a0fa6b0886b2b'), 'latitude': -37.95, 'longitude': 142.366, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('5ce737cc869a0fa6b0886b36'), 'latitude': -36.282, 'longitude': 146.157, 'confidence': 100, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('5ce737cc869a0fa6b0886b46'), 'latitude': -37.642, 'longitude': 149.263, 'confidence': 100, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b0886b47'), 'latitude': -37.634, 'longitude': 149.237, 'confidence': 100, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('5ce737cc869a0fa6b0886b4a'), 'latitude': -37.605, 'longitude': 149.302, 'confidence': 98, 'surface_temperature_celcius': 83}
# {'_id': ObjectId('5ce737cc869a0fa6b0886b4d'), 'latitude': -37.6, 'longitude': 149.325, 'confidence': 99, 'surface_temperature_celcius': 86}
# {'_id': ObjectId('5ce737cc869a0fa6b0886b52'), 'latitude': -37.618, 'longitude': 149.281, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('5ce737cc869a0fa6b0886b5c'), 'latitude': -37.606, 'longitude': 149.312, 'confidence': 100, 'surface_temperature_celcius': 87}
# {'_id': ObjectId('5ce737cc869a0fa6b0886b5e'), 'latitude': -37.61, 'longitude': 149.307, 'confidence': 97, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('5ce737cc869a0fa6b0886b5f'), 'latitude': -37.609, 'longitude': 149.32, 'confidence': 99, 'surface_temperature_celcius': 84}
# {'_id': ObjectId('5ce737cc869a0fa6b0886b62'), 'latitude': -37.945, 'longitude': 144.354, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('5ce737cc869a0fa6b0886b69'), 'latitude': -37.862, 'longitude': 144.175, 'confidence': 87, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b0886b75'), 'latitude': -36.94, 'longitude': 143.281, 'confidence': 89, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('5ce737cc869a0fa6b0886b7f'), 'latitude': -37.477, 'longitude': 143.352, 'confidence': 100, 'surface_temperature_celcius': 93}
# {'_id': ObjectId('5ce737cc869a0fa6b0886b80'), 'latitude': -37.475, 'longitude': 143.365, 'confidence': 96, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('5ce737cc869a0fa6b0886b83'), 'latitude': -37.69, 'longitude': 143.605, 'confidence': 97, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('5ce737cc869a0fa6b0886b88'), 'latitude': -37.331, 'longitude': 143.122, 'confidence': 90, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b0886b99'), 'latitude': -36.098, 'longitude': 143.74, 'confidence': 92, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ba5'), 'latitude': -37.247, 'longitude': 141.278, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ba9'), 'latitude': -37.294, 'longitude': 141.232, 'confidence': 100, 'surface_temperature_celcius': 87}
# {'_id': ObjectId('5ce737cc869a0fa6b0886baa'), 'latitude': -37.293, 'longitude': 141.245, 'confidence': 99, 'surface_temperature_celcius': 85}
# {'_id': ObjectId('5ce737cc869a0fa6b0886bad'), 'latitude': -38.127, 'longitude': 143.82, 'confidence': 96, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('5ce737cc869a0fa6b0886bc6'), 'latitude': -37.462, 'longitude': 148.089, 'confidence': 100, 'surface_temperature_celcius': 90}
# {'_id': ObjectId('5ce737cc869a0fa6b0886bc7'), 'latitude': -37.46, 'longitude': 148.102, 'confidence': 88, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b0886be6'), 'latitude': -37.446, 'longitude': 148.102, 'confidence': 100, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b0886bf5'), 'latitude': -37.406, 'longitude': 148.123, 'confidence': 100, 'surface_temperature_celcius': 88}
# {'_id': ObjectId('5ce737cc869a0fa6b0886bf7'), 'latitude': -37.452, 'longitude': 148.115, 'confidence': 68, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('5ce737cc869a0fa6b0886bf9'), 'latitude': -37.45, 'longitude': 148.126, 'confidence': 64, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('5ce737cc869a0fa6b0886bfa'), 'latitude': -37.436, 'longitude': 148.088, 'confidence': 86, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('5ce737cc869a0fa6b0886bfb'), 'latitude': -37.444, 'longitude': 148.101, 'confidence': 73, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('5ce737cc869a0fa6b0886bfc'), 'latitude': -37.562, 'longitude': 148.05, 'confidence': 61, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('5ce737cc869a0fa6b0886c03'), 'latitude': -37.379, 'longitude': 148.126, 'confidence': 58, 'surface_temperature_celcius': 82}
# {'_id': ObjectId('5ce737cc869a0fa6b0886c04'), 'latitude': -37.379, 'longitude': 148.132, 'confidence': 62, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('5ce737cc869a0fa6b0886c06'), 'latitude': -37.396, 'longitude': 148.086, 'confidence': 100, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b0886c0b'), 'latitude': -37.399, 'longitude': 148.081, 'confidence': 100, 'surface_temperature_celcius': 84}
# {'_id': ObjectId('5ce737cc869a0fa6b0886c0c'), 'latitude': -37.401, 'longitude': 148.067, 'confidence': 100, 'surface_temperature_celcius': 79}
# {'_id': ObjectId('5ce737cc869a0fa6b0886c33'), 'latitude': -37.4796, 'longitude': 141.9403, 'confidence': 94, 'surface_temperature_celcius': 87}
# {'_id': ObjectId('5ce737cc869a0fa6b0886c35'), 'latitude': -38.3998, 'longitude': 147.064, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b0886c3e'), 'latitude': -37.8644, 'longitude': 143.4263, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('5ce737cc869a0fa6b0886c57'), 'latitude': -36.3774, 'longitude': 143.7079, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('5ce737cc869a0fa6b0886c58'), 'latitude': -36.3756, 'longitude': 143.7243, 'confidence': 100, 'surface_temperature_celcius': 88}
# {'_id': ObjectId('5ce737cc869a0fa6b0886c59'), 'latitude': -36.369, 'longitude': 143.7132, 'confidence': 97, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('5ce737cc869a0fa6b0886c5a'), 'latitude': -36.3799, 'longitude': 143.7149, 'confidence': 100, 'surface_temperature_celcius': 89}
# {'_id': ObjectId('5ce737cc869a0fa6b0886c60'), 'latitude': -36.2693, 'longitude': 143.1768, 'confidence': 94, 'surface_temperature_celcius': 85}
# {'_id': ObjectId('5ce737cc869a0fa6b0886c6e'), 'latitude': -36.1002, 'longitude': 142.3405, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('5ce737cc869a0fa6b0886c76'), 'latitude': -36.4325, 'longitude': 144.3142, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('5ce737cc869a0fa6b0886c79'), 'latitude': -36.7685, 'longitude': 142.7134, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('5ce737cc869a0fa6b0886c7c'), 'latitude': -36.7801, 'longitude': 142.7151, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('5ce737cc869a0fa6b0886cac'), 'latitude': -36.7746, 'longitude': 146.6642, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('5ce737cc869a0fa6b0886cae'), 'latitude': -36.8359, 'longitude': 146.6448, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('5ce737cc869a0fa6b0886cb1'), 'latitude': -37.9085, 'longitude': 141.1038, 'confidence': 98, 'surface_temperature_celcius': 82}
# {'_id': ObjectId('5ce737cc869a0fa6b0886cb4'), 'latitude': -38.4349, 'longitude': 146.3122, 'confidence': 100, 'surface_temperature_celcius': 93}
# {'_id': ObjectId('5ce737cc869a0fa6b0886cb5'), 'latitude': -38.4792, 'longitude': 146.3081, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b0886cba'), 'latitude': -37.9047, 'longitude': 141.0945, 'confidence': 100, 'surface_temperature_celcius': 90}
# {'_id': ObjectId('5ce737cc869a0fa6b0886cca'), 'latitude': -37.4984, 'longitude': 142.9739, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ccb'), 'latitude': -37.253, 'longitude': 144.3681, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('5ce737cc869a0fa6b0886cd0'), 'latitude': -36.9396, 'longitude': 143.1462, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('5ce737cc869a0fa6b0886cd7'), 'latitude': -36.3387, 'longitude': 141.7542, 'confidence': 96, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ce5'), 'latitude': -36.3433, 'longitude': 143.4369, 'confidence': 100, 'surface_temperature_celcius': 94}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ce9'), 'latitude': -36.345, 'longitude': 143.4256, 'confidence': 100, 'surface_temperature_celcius': 87}
# {'_id': ObjectId('5ce737cc869a0fa6b0886cea'), 'latitude': -36.7032, 'longitude': 144.0992, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('5ce737cc869a0fa6b0886cf9'), 'latitude': -36.3402, 'longitude': 141.7429, 'confidence': 96, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('5ce737cc869a0fa6b0886cfe'), 'latitude': -36.5661, 'longitude': 142.2956, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d0a'), 'latitude': -36.5023, 'longitude': 143.6038, 'confidence': 85, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d0c'), 'latitude': -36.8616, 'longitude': 142.8025, 'confidence': 90, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d18'), 'latitude': -38.0372, 'longitude': 146.0616, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d19'), 'latitude': -38.049, 'longitude': 146.0513, 'confidence': 94, 'surface_temperature_celcius': 74}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d1c'), 'latitude': -35.4666, 'longitude': 142.0749, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d1f'), 'latitude': -36.0396, 'longitude': 141.7183, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d24'), 'latitude': -36.2775, 'longitude': 146.1026, 'confidence': 94, 'surface_temperature_celcius': 74}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d2b'), 'latitude': -38.0361, 'longitude': 146.0567, 'confidence': 100, 'surface_temperature_celcius': 90}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d30'), 'latitude': -36.3254, 'longitude': 144.3638, 'confidence': 95, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d35'), 'latitude': -36.0816, 'longitude': 145.859, 'confidence': 100, 'surface_temperature_celcius': 98}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d39'), 'latitude': -36.1532, 'longitude': 143.5527, 'confidence': 100, 'surface_temperature_celcius': 90}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d41'), 'latitude': -36.0077, 'longitude': 141.7747, 'confidence': 100, 'surface_temperature_celcius': 93}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d4d'), 'latitude': -36.0828, 'longitude': 145.873, 'confidence': 94, 'surface_temperature_celcius': 75}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d54'), 'latitude': -36.5541, 'longitude': 144.1321, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d57'), 'latitude': -35.6819, 'longitude': 143.5275, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d5a'), 'latitude': -35.6871, 'longitude': 143.5235, 'confidence': 90, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d5f'), 'latitude': -36.1506, 'longitude': 143.5671, 'confidence': 100, 'surface_temperature_celcius': 95}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d68'), 'latitude': -37.4671, 'longitude': 145.9962, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d6e'), 'latitude': -36.2911, 'longitude': 141.1664, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d6f'), 'latitude': -36.2842, 'longitude': 141.1741, 'confidence': 96, 'surface_temperature_celcius': 79}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d71'), 'latitude': -36.7218, 'longitude': 141.6411, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d72'), 'latitude': -37.3656, 'longitude': 141.3903, 'confidence': 84, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d74'), 'latitude': -36.4179, 'longitude': 144.2924, 'confidence': 94, 'surface_temperature_celcius': 75}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d76'), 'latitude': -36.3207, 'longitude': 140.9737, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d79'), 'latitude': -36.2882, 'longitude': 141.1821, 'confidence': 99, 'surface_temperature_celcius': 86}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d7a'), 'latitude': -36.3153, 'longitude': 140.9789, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d7c'), 'latitude': -36.4169, 'longitude': 144.2994, 'confidence': 97, 'surface_temperature_celcius': 81}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d81'), 'latitude': -36.8094, 'longitude': 142.8885, 'confidence': 96, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d91'), 'latitude': -37.8323, 'longitude': 147.2232, 'confidence': 84, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('5ce737cc869a0fa6b0886da1'), 'latitude': -38.2853, 'longitude': 145.9519, 'confidence': 98, 'surface_temperature_celcius': 83}
# {'_id': ObjectId('5ce737cc869a0fa6b0886da2'), 'latitude': -38.2375, 'longitude': 142.8363, 'confidence': 98, 'surface_temperature_celcius': 82}
# {'_id': ObjectId('5ce737cc869a0fa6b0886da4'), 'latitude': -37.4463, 'longitude': 142.7829, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('5ce737cc869a0fa6b0886daf'), 'latitude': -37.6854, 'longitude': 143.4543, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('5ce737cc869a0fa6b0886db5'), 'latitude': -38.0881, 'longitude': 143.9391, 'confidence': 99, 'surface_temperature_celcius': 84}
# {'_id': ObjectId('5ce737cc869a0fa6b0886db6'), 'latitude': -38.0866, 'longitude': 143.9534, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('5ce737cc869a0fa6b0886db7'), 'latitude': -38.2391, 'longitude': 142.82, 'confidence': 92, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('5ce737cc869a0fa6b0886dba'), 'latitude': -38.5123, 'longitude': 146.4007, 'confidence': 100, 'surface_temperature_celcius': 89}
# {'_id': ObjectId('5ce737cc869a0fa6b0886dd7'), 'latitude': -36.3438, 'longitude': 141.5832, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('5ce737cc869a0fa6b0886dde'), 'latitude': -37.4357, 'longitude': 142.7813, 'confidence': 94, 'surface_temperature_celcius': 74}
# {'_id': ObjectId('5ce737cc869a0fa6b0886df2'), 'latitude': -37.5867, 'longitude': 143.6256, 'confidence': 99, 'surface_temperature_celcius': 85}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e01'), 'latitude': -36.2306, 'longitude': 143.6408, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e0b'), 'latitude': -36.4168, 'longitude': 141.6939, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e16'), 'latitude': -36.4211, 'longitude': 141.6875, 'confidence': 97, 'surface_temperature_celcius': 81}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e1e'), 'latitude': -35.6138, 'longitude': 143.8666, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e21'), 'latitude': -36.0885, 'longitude': 145.0359, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e22'), 'latitude': -36.3193, 'longitude': 145.9162, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e24'), 'latitude': -36.0652, 'longitude': 146.0764, 'confidence': 98, 'surface_temperature_celcius': 82}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e26'), 'latitude': -36.0682, 'longitude': 146.0602, 'confidence': 100, 'surface_temperature_celcius': 90}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e2a'), 'latitude': -37.7889, 'longitude': 143.1324, 'confidence': 92, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e2c'), 'latitude': -36.6139, 'longitude': 143.501, 'confidence': 95, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e32'), 'latitude': -37.9509, 'longitude': 143.9599, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e3f'), 'latitude': -36.6224, 'longitude': 143.5092, 'confidence': 97, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e49'), 'latitude': -38.0933, 'longitude': 143.9824, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e4b'), 'latitude': -36.663, 'longitude': 142.8567, 'confidence': 92, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e55'), 'latitude': -37.6982, 'longitude': 143.0549, 'confidence': 94, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e58'), 'latitude': -36.7187, 'longitude': 143.805, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e5b'), 'latitude': -36.7742, 'longitude': 145.1991, 'confidence': 100, 'surface_temperature_celcius': 89}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e64'), 'latitude': -36.5061, 'longitude': 144.5675, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e68'), 'latitude': -36.4035, 'longitude': 140.9935, 'confidence': 100, 'surface_temperature_celcius': 95}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e71'), 'latitude': -36.4286, 'longitude': 141.1567, 'confidence': 99, 'surface_temperature_celcius': 84}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e74'), 'latitude': -36.3635, 'longitude': 142.2809, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e75'), 'latitude': -36.664, 'longitude': 142.8802, 'confidence': 100, 'surface_temperature_celcius': 87}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e77'), 'latitude': -36.6564, 'longitude': 142.8615, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e89'), 'latitude': -36.6657, 'longitude': 143.1675, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e97'), 'latitude': -36.8742, 'longitude': 142.7177, 'confidence': 98, 'surface_temperature_celcius': 84}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e9b'), 'latitude': -36.7751, 'longitude': 145.1696, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e9f'), 'latitude': -36.3961, 'longitude': 140.9781, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ea1'), 'latitude': -36.7708, 'longitude': 145.1908, 'confidence': 100, 'surface_temperature_celcius': 98}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ea5'), 'latitude': -37.758, 'longitude': 143.179, 'confidence': 98, 'surface_temperature_celcius': 82}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ea6'), 'latitude': -37.7609, 'longitude': 143.1633, 'confidence': 94, 'surface_temperature_celcius': 74}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ea7'), 'latitude': -36.5116, 'longitude': 144.562, 'confidence': 89, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ea9'), 'latitude': -36.803, 'longitude': 142.9261, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('5ce737cc869a0fa6b0886eae'), 'latitude': -36.4143, 'longitude': 143.272, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b0886eb2'), 'latitude': -36.7153, 'longitude': 143.8226, 'confidence': 99, 'surface_temperature_celcius': 86}
# {'_id': ObjectId('5ce737cc869a0fa6b0886eb5'), 'latitude': -36.8791, 'longitude': 142.7261, 'confidence': 100, 'surface_temperature_celcius': 93}
# {'_id': ObjectId('5ce737cc869a0fa6b0886eb8'), 'latitude': -36.7309, 'longitude': 142.3633, 'confidence': 100, 'surface_temperature_celcius': 88}
# {'_id': ObjectId('5ce737cc869a0fa6b0886eb9'), 'latitude': -36.882, 'longitude': 142.7108, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ec0'), 'latitude': -37.5135, 'longitude': 142.7238, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ec1'), 'latitude': -36.2121, 'longitude': 144.6885, 'confidence': 94, 'surface_temperature_celcius': 74}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ec6'), 'latitude': -36.2206, 'longitude': 144.6856, 'confidence': 97, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ecb'), 'latitude': -38.0132, 'longitude': 146.5269, 'confidence': 88, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ecd'), 'latitude': -38.0148, 'longitude': 146.5413, 'confidence': 87, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ece'), 'latitude': -37.8412, 'longitude': 147.2536, 'confidence': 100, 'surface_temperature_celcius': 87}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ecf'), 'latitude': -37.8429, 'longitude': 147.2691, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ed2'), 'latitude': -36.5454, 'longitude': 144.7402, 'confidence': 100, 'surface_temperature_celcius': 96}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ed6'), 'latitude': -36.7593, 'longitude': 142.895, 'confidence': 92, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ee0'), 'latitude': -36.3435, 'longitude': 141.5513, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ee6'), 'latitude': -36.6942, 'longitude': 143.8021, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ee9'), 'latitude': -36.3459, 'longitude': 141.5586, 'confidence': 100, 'surface_temperature_celcius': 91}
# {'_id': ObjectId('5ce737cc869a0fa6b0886eee'), 'latitude': -36.4046, 'longitude': 141.1534, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ef3'), 'latitude': -36.0594, 'longitude': 141.5907, 'confidence': 96, 'surface_temperature_celcius': 79}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ef4'), 'latitude': -36.0576, 'longitude': 141.6122, 'confidence': 100, 'surface_temperature_celcius': 94}
# {'_id': ObjectId('5ce737cc869a0fa6b0886efe'), 'latitude': -36.388, 'longitude': 141.8309, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f00'), 'latitude': -36.094, 'longitude': 145.7646, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f09'), 'latitude': -36.5438, 'longitude': 144.7548, 'confidence': 99, 'surface_temperature_celcius': 84}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f0c'), 'latitude': -36.6537, 'longitude': 143.8781, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f12'), 'latitude': -38.1917, 'longitude': 147.0745, 'confidence': 100, 'surface_temperature_celcius': 94}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f14'), 'latitude': -38.1987, 'longitude': 147.0666, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f25'), 'latitude': -36.9303, 'longitude': 143.1034, 'confidence': 70, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f27'), 'latitude': -36.3195, 'longitude': 146.0601, 'confidence': 83, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f28'), 'latitude': -36.5839, 'longitude': 143.0588, 'confidence': 100, 'surface_temperature_celcius': 99}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f29'), 'latitude': -36.5854, 'longitude': 143.0462, 'confidence': 100, 'surface_temperature_celcius': 94}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f2b'), 'latitude': -36.3014, 'longitude': 143.203, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f30'), 'latitude': -36.3332, 'longitude': 145.8594, 'confidence': 87, 'surface_temperature_celcius': 90}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f3b'), 'latitude': -37.6775, 'longitude': 148.5131, 'confidence': 86, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f46'), 'latitude': -36.9111, 'longitude': 142.692, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f4c'), 'latitude': -37.5115, 'longitude': 143.14, 'confidence': 99, 'surface_temperature_celcius': 86}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f57'), 'latitude': -37.769, 'longitude': 147.94, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f5a'), 'latitude': -36.1303, 'longitude': 146.3606, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f61'), 'latitude': -36.1345, 'longitude': 146.351, 'confidence': 98, 'surface_temperature_celcius': 84}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f68'), 'latitude': -36.1586, 'longitude': 145.6666, 'confidence': 99, 'surface_temperature_celcius': 85}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f6c'), 'latitude': -36.5847, 'longitude': 145.1968, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f7f'), 'latitude': -37.876, 'longitude': 143.7804, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f80'), 'latitude': -36.1546, 'longitude': 141.8146, 'confidence': 88, 'surface_temperature_celcius': 74}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f83'), 'latitude': -37.9091, 'longitude': 143.5105, 'confidence': 87, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f87'), 'latitude': -36.1559, 'longitude': 141.8102, 'confidence': 80, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f8b'), 'latitude': -37.9071, 'longitude': 143.538, 'confidence': 100, 'surface_temperature_celcius': 88}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f91'), 'latitude': -37.3902, 'longitude': 148.2955, 'confidence': 100, 'surface_temperature_celcius': 98}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f93'), 'latitude': -37.5027, 'longitude': 146.347, 'confidence': 100, 'surface_temperature_celcius': 95}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f94'), 'latitude': -37.5043, 'longitude': 146.3299, 'confidence': 100, 'surface_temperature_celcius': 93}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f9f'), 'latitude': -36.1964, 'longitude': 144.5217, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('5ce737cc869a0fa6b0886fac'), 'latitude': -37.6397, 'longitude': 142.5968, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('5ce737cc869a0fa6b0886fb1'), 'latitude': -37.6267, 'longitude': 142.9993, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('5ce737cc869a0fa6b0886fba'), 'latitude': -36.5871, 'longitude': 144.4958, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('5ce737cc869a0fa6b0886fbd'), 'latitude': -36.2618, 'longitude': 141.8783, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b0886fbf'), 'latitude': -36.6828, 'longitude': 144.784, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('5ce737cc869a0fa6b0886fc2'), 'latitude': -37.4843, 'longitude': 143.0592, 'confidence': 89, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('5ce737cc869a0fa6b0886fdb'), 'latitude': -37.7274, 'longitude': 142.9536, 'confidence': 94, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('5ce737cc869a0fa6b0886fdc'), 'latitude': -37.6964, 'longitude': 142.8583, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('5ce737cc869a0fa6b0886fe0'), 'latitude': -38.0509, 'longitude': 143.9423, 'confidence': 98, 'surface_temperature_celcius': 82}
# {'_id': ObjectId('5ce737cc869a0fa6b0886fe2'), 'latitude': -37.9284, 'longitude': 143.108, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('5ce737cc869a0fa6b0886fe6'), 'latitude': -37.5701, 'longitude': 142.6497, 'confidence': 100, 'surface_temperature_celcius': 94}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ff0'), 'latitude': -36.7101, 'longitude': 142.3865, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ff5'), 'latitude': -38.1693, 'longitude': 143.0466, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ff7'), 'latitude': -36.7128, 'longitude': 142.3717, 'confidence': 95, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('5ce737cc869a0fa6b0886ff8'), 'latitude': -37.4885, 'longitude': 142.0658, 'confidence': 97, 'surface_temperature_celcius': 81}
# {'_id': ObjectId('5ce737cc869a0fa6b0887004'), 'latitude': -36.7101, 'longitude': 142.981, 'confidence': 77, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('5ce737cc869a0fa6b0887005'), 'latitude': -37.0959, 'longitude': 143.8206, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b0887009'), 'latitude': -37.9594, 'longitude': 143.5638, 'confidence': 100, 'surface_temperature_celcius': 87}
# {'_id': ObjectId('5ce737cc869a0fa6b088700f'), 'latitude': -36.5921, 'longitude': 144.4905, 'confidence': 98, 'surface_temperature_celcius': 82}
# {'_id': ObjectId('5ce737cc869a0fa6b088701b'), 'latitude': -36.6787, 'longitude': 144.8042, 'confidence': 96, 'surface_temperature_celcius': 79}
# {'_id': ObjectId('5ce737cc869a0fa6b0887023'), 'latitude': -38.0423, 'longitude': 146.4048, 'confidence': 84, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('5ce737cc869a0fa6b088702c'), 'latitude': -38.1224, 'longitude': 143.7553, 'confidence': 94, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('5ce737cc869a0fa6b0887031'), 'latitude': -38.0792, 'longitude': 143.7361, 'confidence': 94, 'surface_temperature_celcius': 93}
# {'_id': ObjectId('5ce737cc869a0fa6b0887041'), 'latitude': -37.9157, 'longitude': 143.3544, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('5ce737cc869a0fa6b0887056'), 'latitude': -37.7935, 'longitude': 143.1606, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('5ce737cc869a0fa6b0887059'), 'latitude': -37.7756, 'longitude': 143.1388, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('5ce737cc869a0fa6b0887062'), 'latitude': -37.7171, 'longitude': 142.9505, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('5ce737cc869a0fa6b0887063'), 'latitude': -37.7236, 'longitude': 142.947, 'confidence': 94, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('5ce737cc869a0fa6b0887065'), 'latitude': -37.7002, 'longitude': 142.9562, 'confidence': 100, 'surface_temperature_celcius': 89}
# {'_id': ObjectId('5ce737cc869a0fa6b088706f'), 'latitude': -37.6498, 'longitude': 142.5997, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('5ce737cc869a0fa6b0887073'), 'latitude': -37.5728, 'longitude': 142.6348, 'confidence': 100, 'surface_temperature_celcius': 98}
# {'_id': ObjectId('5ce737cc869a0fa6b0887076'), 'latitude': -37.4352, 'longitude': 143.1444, 'confidence': 100, 'surface_temperature_celcius': 96}
# {'_id': ObjectId('5ce737cc869a0fa6b088709a'), 'latitude': -36.5828, 'longitude': 144.5775, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('5ce737cc869a0fa6b088709b'), 'latitude': -36.5987, 'longitude': 144.4995, 'confidence': 96, 'surface_temperature_celcius': 79}
# {'_id': ObjectId('5ce737cc869a0fa6b08870a5'), 'latitude': -36.5262, 'longitude': 144.5737, 'confidence': 98, 'surface_temperature_celcius': 84}
# {'_id': ObjectId('5ce737cc869a0fa6b08870af'), 'latitude': -36.6995, 'longitude': 142.978, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('5ce737cc869a0fa6b08870b4'), 'latitude': -36.8879, 'longitude': 141.6647, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('5ce737cc869a0fa6b08870c0'), 'latitude': -35.8768, 'longitude': 145.4627, 'confidence': 100, 'surface_temperature_celcius': 86}
# {'_id': ObjectId('5ce737cc869a0fa6b08870c1'), 'latitude': -36.4899, 'longitude': 142.2805, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('5ce737cc869a0fa6b08870c3'), 'latitude': -36.663, 'longitude': 141.3038, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('5ce737cc869a0fa6b08870cf'), 'latitude': -36.092, 'longitude': 141.7306, 'confidence': 94, 'surface_temperature_celcius': 75}
# {'_id': ObjectId('5ce737cc869a0fa6b08870d1'), 'latitude': -34.9023, 'longitude': 142.0557, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b08870d7'), 'latitude': -36.2637, 'longitude': 145.3649, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('5ce737cc869a0fa6b08870d8'), 'latitude': -37.2609, 'longitude': 141.7999, 'confidence': 89, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('5ce737cc869a0fa6b08870db'), 'latitude': -36.91, 'longitude': 141.0704, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('5ce737cc869a0fa6b08870e1'), 'latitude': -36.2652, 'longitude': 145.3769, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('5ce737cc869a0fa6b08870e3'), 'latitude': -36.738, 'longitude': 142.1177, 'confidence': 95, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('5ce737cc869a0fa6b08870fb'), 'latitude': -36.5199, 'longitude': 144.7311, 'confidence': 95, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('5ce737cc869a0fa6b08870ff'), 'latitude': -37.0782, 'longitude': 145.3625, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('5ce737cc869a0fa6b0887105'), 'latitude': -36.3966, 'longitude': 141.406, 'confidence': 94, 'surface_temperature_celcius': 74}
# {'_id': ObjectId('5ce737cc869a0fa6b0887108'), 'latitude': -37.1349, 'longitude': 141.9491, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('5ce737cc869a0fa6b0887118'), 'latitude': -36.7651, 'longitude': 143.5801, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('5ce737cc869a0fa6b0887123'), 'latitude': -36.9329, 'longitude': 143.7796, 'confidence': 98, 'surface_temperature_celcius': 82}
# {'_id': ObjectId('5ce737cc869a0fa6b0887126'), 'latitude': -35.8276, 'longitude': 143.7549, 'confidence': 99, 'surface_temperature_celcius': 85}
# {'_id': ObjectId('5ce737cc869a0fa6b0887137'), 'latitude': -35.9326, 'longitude': 141.958, 'confidence': 78, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('5ce737cc869a0fa6b088713f'), 'latitude': -36.6892, 'longitude': 145.2775, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('5ce737cc869a0fa6b0887140'), 'latitude': -36.73, 'longitude': 143.935, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b0887142'), 'latitude': -36.8283, 'longitude': 143.4605, 'confidence': 100, 'surface_temperature_celcius': 93}
# {'_id': ObjectId('5ce737cc869a0fa6b0887147'), 'latitude': -36.6527, 'longitude': 142.7392, 'confidence': 97, 'surface_temperature_celcius': 81}
# {'_id': ObjectId('5ce737cc869a0fa6b0887148'), 'latitude': -36.1898, 'longitude': 145.0922, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('5ce737cc869a0fa6b088714e'), 'latitude': -36.8298, 'longitude': 143.4483, 'confidence': 96, 'surface_temperature_celcius': 79}
# {'_id': ObjectId('5ce737cc869a0fa6b0887151'), 'latitude': -36.6615, 'longitude': 144.6014, 'confidence': 100, 'surface_temperature_celcius': 90}
# {'_id': ObjectId('5ce737cc869a0fa6b0887152'), 'latitude': -36.8238, 'longitude': 143.5724, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('5ce737cc869a0fa6b0887165'), 'latitude': -36.1988, 'longitude': 145.0941, 'confidence': 100, 'surface_temperature_celcius': 100}
# {'_id': ObjectId('5ce737cc869a0fa6b0887167'), 'latitude': -36.7499, 'longitude': 141.3006, 'confidence': 75, 'surface_temperature_celcius': 99}
# {'_id': ObjectId('5ce737cc869a0fa6b088716e'), 'latitude': -36.7432, 'longitude': 141.3296, 'confidence': 84, 'surface_temperature_celcius': 79}
# {'_id': ObjectId('5ce737cc869a0fa6b0887170'), 'latitude': -36.7531, 'longitude': 141.3253, 'confidence': 84, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('5ce737cc869a0fa6b0887174'), 'latitude': -36.7943, 'longitude': 143.9571, 'confidence': 99, 'surface_temperature_celcius': 84}
# {'_id': ObjectId('5ce737cc869a0fa6b0887176'), 'latitude': -36.7957, 'longitude': 143.9652, 'confidence': 100, 'surface_temperature_celcius': 87}
# {'_id': ObjectId('5ce737cc869a0fa6b0887179'), 'latitude': -36.9498, 'longitude': 142.2012, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('5ce737cc869a0fa6b088717a'), 'latitude': -36.1941, 'longitude': 143.1604, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('5ce737cc869a0fa6b088717b'), 'latitude': -36.4142, 'longitude': 143.1077, 'confidence': 100, 'surface_temperature_celcius': 97}
# {'_id': ObjectId('5ce737cc869a0fa6b088717d'), 'latitude': -36.1924, 'longitude': 143.1716, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('5ce737cc869a0fa6b0887181'), 'latitude': -36.0295, 'longitude': 143.6409, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b0887188'), 'latitude': -37.0761, 'longitude': 141.0574, 'confidence': 100, 'surface_temperature_celcius': 89}
# {'_id': ObjectId('5ce737cc869a0fa6b088718a'), 'latitude': -35.0616, 'longitude': 141.4417, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('5ce737cc869a0fa6b088718b'), 'latitude': -36.3999, 'longitude': 144.737, 'confidence': 100, 'surface_temperature_celcius': 88}
# {'_id': ObjectId('5ce737cc869a0fa6b0887191'), 'latitude': -36.1748, 'longitude': 145.7582, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('5ce737cc869a0fa6b0887192'), 'latitude': -36.0691, 'longitude': 145.7797, 'confidence': 99, 'surface_temperature_celcius': 85}
# {'_id': ObjectId('5ce737cc869a0fa6b0887195'), 'latitude': -35.1949, 'longitude': 141.0622, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('5ce737cc869a0fa6b0887198'), 'latitude': -36.91, 'longitude': 141.2705, 'confidence': 100, 'surface_temperature_celcius': 96}
# {'_id': ObjectId('5ce737cc869a0fa6b088719b'), 'latitude': -35.8071, 'longitude': 142.7318, 'confidence': 89, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('5ce737cc869a0fa6b088719d'), 'latitude': -36.7787, 'longitude': 141.4449, 'confidence': 97, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('5ce737cc869a0fa6b08871ae'), 'latitude': -36.2948, 'longitude': 141.3486, 'confidence': 98, 'surface_temperature_celcius': 82}
# {'_id': ObjectId('5ce737cc869a0fa6b08871af'), 'latitude': -38.1561, 'longitude': 143.7846, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b08871b1'), 'latitude': -37.8185, 'longitude': 142.5609, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('5ce737cc869a0fa6b08871c4'), 'latitude': -36.1771, 'longitude': 145.7451, 'confidence': 100, 'surface_temperature_celcius': 93}
# {'_id': ObjectId('5ce737cc869a0fa6b08871c7'), 'latitude': -38.027, 'longitude': 142.3844, 'confidence': 100, 'surface_temperature_celcius': 95}
# {'_id': ObjectId('5ce737cc869a0fa6b08871c9'), 'latitude': -35.7642, 'longitude': 143.3321, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b08871ce'), 'latitude': -36.429, 'longitude': 141.5759, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('5ce737cc869a0fa6b08871cf'), 'latitude': -36.1346, 'longitude': 145.2196, 'confidence': 92, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('5ce737cc869a0fa6b08871d3'), 'latitude': -37.0899, 'longitude': 141.0238, 'confidence': 100, 'surface_temperature_celcius': 90}
# {'_id': ObjectId('5ce737cc869a0fa6b08871e0'), 'latitude': -36.3823, 'longitude': 141.3146, 'confidence': 95, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('5ce737cc869a0fa6b08871e1'), 'latitude': -36.1462, 'longitude': 145.2096, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('5ce737cc869a0fa6b08871e3'), 'latitude': -36.5243, 'longitude': 142.0839, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('5ce737cc869a0fa6b08871eb'), 'latitude': -37.618, 'longitude': 143.0013, 'confidence': 98, 'surface_temperature_celcius': 82}
# {'_id': ObjectId('5ce737cc869a0fa6b08871ec'), 'latitude': -36.8867, 'longitude': 142.1873, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('5ce737cc869a0fa6b08871ee'), 'latitude': -36.9364, 'longitude': 143.4996, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('5ce737cc869a0fa6b08871f0'), 'latitude': -37.3847, 'longitude': 142.8935, 'confidence': 100, 'surface_temperature_celcius': 88}
# {'_id': ObjectId('5ce737cc869a0fa6b08871f7'), 'latitude': -35.6374, 'longitude': 142.3787, 'confidence': 100, 'surface_temperature_celcius': 95}
# {'_id': ObjectId('5ce737cc869a0fa6b08871f8'), 'latitude': -36.8835, 'longitude': 142.2098, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('5ce737cc869a0fa6b08871f9'), 'latitude': -36.4125, 'longitude': 143.1189, 'confidence': 100, 'surface_temperature_celcius': 92}
# {'_id': ObjectId('5ce737cc869a0fa6b08871fd'), 'latitude': -37.0669, 'longitude': 141.0556, 'confidence': 97, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('5ce737cc869a0fa6b0887200'), 'latitude': -36.0714, 'longitude': 145.7665, 'confidence': 92, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('5ce737cc869a0fa6b088720c'), 'latitude': -36.2933, 'longitude': 141.36, 'confidence': 94, 'surface_temperature_celcius': 75}
# {'_id': ObjectId('5ce737cc869a0fa6b088720f'), 'latitude': -37.4591, 'longitude': 144.9492, 'confidence': 100, 'surface_temperature_celcius': 89}
# {'_id': ObjectId('5ce737cc869a0fa6b0887211'), 'latitude': -36.3487, 'longitude': 145.5315, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('5ce737cc869a0fa6b0887221'), 'latitude': -36.5399, 'longitude': 144.678, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('5ce737cc869a0fa6b0887224'), 'latitude': -36.8158, 'longitude': 142.6229, 'confidence': 97, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('5ce737cc869a0fa6b0887225'), 'latitude': -36.4518, 'longitude': 144.7752, 'confidence': 100, 'surface_temperature_celcius': 97}
# {'_id': ObjectId('5ce737cc869a0fa6b0887227'), 'latitude': -36.7903, 'longitude': 141.618, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('5ce737cc869a0fa6b0887233'), 'latitude': -36.1067, 'longitude': 143.7948, 'confidence': 97, 'surface_temperature_celcius': 79}
# {'_id': ObjectId('5ce737cc869a0fa6b0887234'), 'latitude': -36.1441, 'longitude': 145.2221, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b088723d'), 'latitude': -36.4816, 'longitude': 141.6635, 'confidence': 94, 'surface_temperature_celcius': 75}
# {'_id': ObjectId('5ce737cc869a0fa6b088723f'), 'latitude': -36.0837, 'longitude': 144.2448, 'confidence': 100, 'surface_temperature_celcius': 87}
# {'_id': ObjectId('5ce737cc869a0fa6b0887244'), 'latitude': -36.782, 'longitude': 141.8851, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('5ce737cc869a0fa6b088724d'), 'latitude': -36.5586, 'longitude': 144.0423, 'confidence': 92, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('5ce737cc869a0fa6b088724e'), 'latitude': -36.5568, 'longitude': 144.0538, 'confidence': 90, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('5ce737cc869a0fa6b088724f'), 'latitude': -36.4538, 'longitude': 144.763, 'confidence': 97, 'surface_temperature_celcius': 81}
# {'_id': ObjectId('5ce737cc869a0fa6b0887251'), 'latitude': -36.4612, 'longitude': 144.7775, 'confidence': 91, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('5ce737cc869a0fa6b0887254'), 'latitude': -36.7089, 'longitude': 143.3518, 'confidence': 100, 'surface_temperature_celcius': 93}
# {'_id': ObjectId('5ce737cc869a0fa6b088725f'), 'latitude': -36.601, 'longitude': 144.6378, 'confidence': 97, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('5ce737cc869a0fa6b0887268'), 'latitude': -36.8681, 'longitude': 143.5186, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('5ce737cc869a0fa6b0887272'), 'latitude': -37.1999, 'longitude': 143.8231, 'confidence': 100, 'surface_temperature_celcius': 90}
# {'_id': ObjectId('5ce737cc869a0fa6b088727e'), 'latitude': -37.6171, 'longitude': 142.9426, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('5ce737cc869a0fa6b0887285'), 'latitude': -37.7587, 'longitude': 142.8521, 'confidence': 84, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('5ce737cc869a0fa6b0887289'), 'latitude': -37.4611, 'longitude': 144.9371, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('5ce737cc869a0fa6b0887293'), 'latitude': -38.0254, 'longitude': 142.3959, 'confidence': 100, 'surface_temperature_celcius': 99}
# {'_id': ObjectId('5ce737cc869a0fa6b0887298'), 'latitude': -37.88, 'longitude': 143.7233, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b088729b'), 'latitude': -37.8885, 'longitude': 143.9157, 'confidence': 99, 'surface_temperature_celcius': 85}
# {'_id': ObjectId('5ce737cc869a0fa6b088729f'), 'latitude': -35.0706, 'longitude': 141.4435, 'confidence': 95, 'surface_temperature_celcius': 75}
# {'_id': ObjectId('5ce737cc869a0fa6b08872a0'), 'latitude': -38.0795, 'longitude': 143.2449, 'confidence': 100, 'surface_temperature_celcius': 91}
# {'_id': ObjectId('5ce737cc869a0fa6b08872a3'), 'latitude': -35.1857, 'longitude': 141.0604, 'confidence': 100, 'surface_temperature_celcius': 92}
# {'_id': ObjectId('5ce737cc869a0fa6b08872ac'), 'latitude': -35.6469, 'longitude': 142.376, 'confidence': 100, 'surface_temperature_celcius': 93}
# {'_id': ObjectId('5ce737cc869a0fa6b08872ad'), 'latitude': -35.6453, 'longitude': 142.387, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('5ce737cc869a0fa6b08872b2'), 'latitude': -36.4409, 'longitude': 141.6948, 'confidence': 100, 'surface_temperature_celcius': 92}
# {'_id': ObjectId('5ce737cc869a0fa6b08872b5'), 'latitude': -37.9174, 'longitude': 145.8678, 'confidence': 100, 'surface_temperature_celcius': 93}
# {'_id': ObjectId('5ce737cc869a0fa6b08872b6'), 'latitude': -37.9152, 'longitude': 145.8808, 'confidence': 95, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('5ce737cc869a0fa6b08872b9'), 'latitude': -37.8906, 'longitude': 146.2035, 'confidence': 95, 'surface_temperature_celcius': 75}
# {'_id': ObjectId('5ce737cc869a0fa6b08872c2'), 'latitude': -35.8182, 'longitude': 143.8739, 'confidence': 100, 'surface_temperature_celcius': 92}
# {'_id': ObjectId('5ce737cc869a0fa6b08872c5'), 'latitude': -37.9246, 'longitude': 146.2464, 'confidence': 100, 'surface_temperature_celcius': 96}
# {'_id': ObjectId('5ce737cc869a0fa6b08872c6'), 'latitude': -36.3313, 'longitude': 141.0017, 'confidence': 94, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('5ce737cc869a0fa6b08872c8'), 'latitude': -36.2857, 'longitude': 141.3467, 'confidence': 90, 'surface_temperature_celcius': 67}
# ...
# {'_id': ObjectId('5ce737cc869a0fa6b088737d'), 'latitude': -37.8062, 'longitude': 143.3598, 'confidence': 77, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b088737f'), 'latitude': -36.9918, 'longitude': 141.8667, 'confidence': 100, 'surface_temperature_celcius': 97}
# {'_id': ObjectId('5ce737cc869a0fa6b0887381'), 'latitude': -36.1104, 'longitude': 145.9829, 'confidence': 90, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('5ce737cc869a0fa6b0887382'), 'latitude': -37.782, 'longitude': 148.3844, 'confidence': 100, 'surface_temperature_celcius': 99}
# {'_id': ObjectId('5ce737cc869a0fa6b0887388'), 'latitude': -36.9902, 'longitude': 141.879, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b0887389'), 'latitude': -37.745, 'longitude': 142.993, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b088738d'), 'latitude': -36.0157, 'longitude': 145.9414, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('5ce737cc869a0fa6b0887391'), 'latitude': -37.777, 'longitude': 148.4128, 'confidence': 99, 'surface_temperature_celcius': 85}
# {'_id': ObjectId('5ce737cc869a0fa6b0887392'), 'latitude': -37.5888, 'longitude': 148.5949, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('5ce737cc869a0fa6b0887394'), 'latitude': -34.3943, 'longitude': 141.7567, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b088739c'), 'latitude': -36.0844, 'longitude': 141.4934, 'confidence': 81, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('5ce737cc869a0fa6b08873a1'), 'latitude': -36.031, 'longitude': 145.6824, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('5ce737cc869a0fa6b08873a3'), 'latitude': -37.5814, 'longitude': 148.5777, 'confidence': 86, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('5ce737cc869a0fa6b08873a6'), 'latitude': -37.5788, 'longitude': 148.592, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('5ce737cc869a0fa6b08873a8'), 'latitude': -36.6384, 'longitude': 142.4075, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('5ce737cc869a0fa6b08873ad'), 'latitude': -35.811, 'longitude': 142.1403, 'confidence': 94, 'surface_temperature_celcius': 96}
# {'_id': ObjectId('5ce737cc869a0fa6b08873b3'), 'latitude': -36.9034, 'longitude': 141.0013, 'confidence': 100, 'surface_temperature_celcius': 95}
# {'_id': ObjectId('5ce737cc869a0fa6b08873b4'), 'latitude': -37.7746, 'longitude': 148.3673, 'confidence': 88, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b08873b9'), 'latitude': -37.803, 'longitude': 142.3151, 'confidence': 83, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('5ce737cc869a0fa6b08873bc'), 'latitude': -37.7542, 'longitude': 142.9949, 'confidence': 96, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('5ce737cc869a0fa6b08873bd'), 'latitude': -37.3803, 'longitude': 145.611, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('5ce737cc869a0fa6b08873be'), 'latitude': -37.7617, 'longitude': 143.081, 'confidence': 97, 'surface_temperature_celcius': 81}
# {'_id': ObjectId('5ce737cc869a0fa6b08873c1'), 'latitude': -37.8161, 'longitude': 142.9286, 'confidence': 92, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('5ce737cc869a0fa6b08873d2'), 'latitude': -36.0387, 'longitude': 145.6787, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('5ce737cc869a0fa6b08873d4'), 'latitude': -36.6349, 'longitude': 142.2125, 'confidence': 94, 'surface_temperature_celcius': 86}
# {'_id': ObjectId('5ce737cc869a0fa6b08873da'), 'latitude': -36.9018, 'longitude': 141.0146, 'confidence': 100, 'surface_temperature_celcius': 100}
# {'_id': ObjectId('5ce737cc869a0fa6b08873db'), 'latitude': -36.6986, 'longitude': 142.7259, 'confidence': 86, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('5ce737cc869a0fa6b08873e6'), 'latitude': -38.0052, 'longitude': 142.6179, 'confidence': 94, 'surface_temperature_celcius': 89}
# {'_id': ObjectId('5ce737cc869a0fa6b08873fc'), 'latitude': -37.6387, 'longitude': 142.9032, 'confidence': 87, 'surface_temperature_celcius': 88}
# {'_id': ObjectId('5ce737cc869a0fa6b0887400'), 'latitude': -37.6439, 'longitude': 142.913, 'confidence': 93, 'surface_temperature_celcius': 83}
# {'_id': ObjectId('5ce737cc869a0fa6b0887405'), 'latitude': -37.3165, 'longitude': 147.4932, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('5ce737cc869a0fa6b0887409'), 'latitude': -37.3158, 'longitude': 147.4986, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('5ce737cc869a0fa6b088740b'), 'latitude': -37.4471, 'longitude': 147.6331, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b088740e'), 'latitude': -37.7835, 'longitude': 148.4138, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('5ce737cc869a0fa6b0887411'), 'latitude': -37.4449, 'longitude': 147.6594, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b0887413'), 'latitude': -37.4323, 'longitude': 147.6583, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('5ce737cc869a0fa6b0887414'), 'latitude': -37.4343, 'longitude': 147.6327, 'confidence': 100, 'surface_temperature_celcius': 92}
# {'_id': ObjectId('5ce737cc869a0fa6b0887426'), 'latitude': -35.4033, 'longitude': 143.267, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('5ce737cc869a0fa6b0887427'), 'latitude': -36.6281, 'longitude': 142.4349, 'confidence': 64, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('5ce737cc869a0fa6b0887428'), 'latitude': -36.111, 'longitude': 145.124, 'confidence': 85, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('5ce737cc869a0fa6b0887429'), 'latitude': -36.1615, 'longitude': 141.8728, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('5ce737cc869a0fa6b088743c'), 'latitude': -36.1122, 'longitude': 142.1491, 'confidence': 90, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('5ce737cc869a0fa6b088743f'), 'latitude': -37.3735, 'longitude': 145.8384, 'confidence': 100, 'surface_temperature_celcius': 95}
# {'_id': ObjectId('5ce737cc869a0fa6b0887442'), 'latitude': -35.4255, 'longitude': 143.6306, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b0887445'), 'latitude': -36.1955, 'longitude': 145.914, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('5ce737cc869a0fa6b0887446'), 'latitude': -35.4533, 'longitude': 143.2029, 'confidence': 85, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('5ce737cc869a0fa6b0887448'), 'latitude': -36.5989, 'longitude': 141.9771, 'confidence': 92, 'surface_temperature_celcius': 81}
# {'_id': ObjectId('5ce737cc869a0fa6b0887451'), 'latitude': -36.6299, 'longitude': 142.4234, 'confidence': 66, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('5ce737cc869a0fa6b0887456'), 'latitude': -36.1925, 'longitude': 145.93, 'confidence': 97, 'surface_temperature_celcius': 79}
# {'_id': ObjectId('5ce737cc869a0fa6b0887458'), 'latitude': -36.095, 'longitude': 141.7699, 'confidence': 98, 'surface_temperature_celcius': 82}
# {'_id': ObjectId('5ce737cc869a0fa6b0887462'), 'latitude': -36.6006, 'longitude': 141.9657, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('5ce737cc869a0fa6b0887464'), 'latitude': -37.0769, 'longitude': 141.042, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('5ce737cc869a0fa6b0887467'), 'latitude': -36.883, 'longitude': 142.1637, 'confidence': 79, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('5ce737cc869a0fa6b0887468'), 'latitude': -36.0973, 'longitude': 143.4279, 'confidence': 87, 'surface_temperature_celcius': 92}
# {'_id': ObjectId('5ce737cc869a0fa6b0887472'), 'latitude': -36.1819, 'longitude': 145.9269, 'confidence': 100, 'surface_temperature_celcius': 98}
# {'_id': ObjectId('5ce737cc869a0fa6b088747c'), 'latitude': -37.3735, 'longitude': 145.886, 'confidence': 87, 'surface_temperature_celcius': 96}
# {'_id': ObjectId('5ce737cc869a0fa6b088747e'), 'latitude': -37.7465, 'longitude': 143.3806, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('5ce737cc869a0fa6b0887483'), 'latitude': -37.8072, 'longitude': 145.9738, 'confidence': 95, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('5ce737cc869a0fa6b0887484'), 'latitude': -37.3704, 'longitude': 145.8942, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('5ce737cc869a0fa6b0887485'), 'latitude': -37.297, 'longitude': 143.5753, 'confidence': 100, 'surface_temperature_celcius': 93}
# {'_id': ObjectId('5ce737cc869a0fa6b088748d'), 'latitude': -37.2988, 'longitude': 143.5487, 'confidence': 100, 'surface_temperature_celcius': 90}
# {'_id': ObjectId('5ce737cc869a0fa6b0887492'), 'latitude': -37.3025, 'longitude': 143.5714, 'confidence': 100, 'surface_temperature_celcius': 98}
# {'_id': ObjectId('5ce737cc869a0fa6b0887493'), 'latitude': -37.383, 'longitude': 145.9089, 'confidence': 100, 'surface_temperature_celcius': 89}
# {'_id': ObjectId('5ce737cc869a0fa6b0887498'), 'latitude': -37.7446, 'longitude': 143.4085, 'confidence': 89, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('5ce737cc869a0fa6b088749d'), 'latitude': -37.7509, 'longitude': 143.4023, 'confidence': 98, 'surface_temperature_celcius': 82}
# {'_id': ObjectId('5ce737cc869a0fa6b08874a0'), 'latitude': -37.7974, 'longitude': 145.9535, 'confidence': 87, 'surface_temperature_celcius': 97}
# {'_id': ObjectId('5ce737cc869a0fa6b08874a5'), 'latitude': -35.7657, 'longitude': 142.0906, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('5ce737cc869a0fa6b08874ad'), 'latitude': -37.7236, 'longitude': 143.3995, 'confidence': 99, 'surface_temperature_celcius': 86}
# {'_id': ObjectId('5ce737cc869a0fa6b08874af'), 'latitude': -37.3046, 'longitude': 143.5448, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('5ce737cc869a0fa6b08874b2'), 'latitude': -36.4312, 'longitude': 141.2064, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('5ce737cc869a0fa6b08874b5'), 'latitude': -36.1556, 'longitude': 141.5904, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b08874b8'), 'latitude': -35.7647, 'longitude': 142.0858, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b08874e4'), 'latitude': -36.4557, 'longitude': 142.2434, 'confidence': 92, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('5ce737cc869a0fa6b08874e5'), 'latitude': -36.8009, 'longitude': 142.7259, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('5ce737cc869a0fa6b08874e7'), 'latitude': -36.8099, 'longitude': 142.728, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('5ce737cc869a0fa6b08874ec'), 'latitude': -36.7806, 'longitude': 141.5597, 'confidence': 94, 'surface_temperature_celcius': 74}
# {'_id': ObjectId('5ce737cc869a0fa6b08874ef'), 'latitude': -34.3526, 'longitude': 141.6458, 'confidence': 98, 'surface_temperature_celcius': 82}
# {'_id': ObjectId('5ce737cc869a0fa6b08874f1'), 'latitude': -37.0924, 'longitude': 141.897, 'confidence': 97, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('5ce737cc869a0fa6b08874f9'), 'latitude': -37.9452, 'longitude': 143.5834, 'confidence': 97, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('5ce737cc869a0fa6b08874ff'), 'latitude': -34.351, 'longitude': 141.6567, 'confidence': 99, 'surface_temperature_celcius': 86}
# {'_id': ObjectId('5ce737cc869a0fa6b0887505'), 'latitude': -37.5012, 'longitude': 142.5853, 'confidence': 100, 'surface_temperature_celcius': 90}
# {'_id': ObjectId('5ce737cc869a0fa6b0887509'), 'latitude': -37.9247, 'longitude': 142.8999, 'confidence': 97, 'surface_temperature_celcius': 81}
# {'_id': ObjectId('5ce737cc869a0fa6b0887511'), 'latitude': -35.0805, 'longitude': 142.4642, 'confidence': 97, 'surface_temperature_celcius': 81}
# {'_id': ObjectId('5ce737cc869a0fa6b088751e'), 'latitude': -37.522, 'longitude': 143.3874, 'confidence': 71, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('5ce737cc869a0fa6b088751f'), 'latitude': -38.0674, 'longitude': 142.965, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('5ce737cc869a0fa6b0887520'), 'latitude': -38.0715, 'longitude': 142.9591, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('5ce737cc869a0fa6b0887521'), 'latitude': -38.0693, 'longitude': 142.9722, 'confidence': 100, 'surface_temperature_celcius': 89}
# {'_id': ObjectId('5ce737cc869a0fa6b088752b'), 'latitude': -37.8973, 'longitude': 143.4754, 'confidence': 82, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b088752d'), 'latitude': -37.7805, 'longitude': 143.5003, 'confidence': 95, 'surface_temperature_celcius': 75}
# {'_id': ObjectId('5ce737cc869a0fa6b0887530'), 'latitude': -37.8774, 'longitude': 145.8213, 'confidence': 95, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('5ce737cc869a0fa6b0887532'), 'latitude': -37.8881, 'longitude': 145.8229, 'confidence': 100, 'surface_temperature_celcius': 99}
# {'_id': ObjectId('5ce737cc869a0fa6b0887539'), 'latitude': -37.6622, 'longitude': 142.1001, 'confidence': 96, 'surface_temperature_celcius': 79}
# {'_id': ObjectId('5ce737cc869a0fa6b088753c'), 'latitude': -37.4523, 'longitude': 147.0175, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('5ce737cc869a0fa6b0887542'), 'latitude': -37.4261, 'longitude': 147.0323, 'confidence': 98, 'surface_temperature_celcius': 83}
# {'_id': ObjectId('5ce737cc869a0fa6b0887543'), 'latitude': -37.3949, 'longitude': 147.0175, 'confidence': 100, 'surface_temperature_celcius': 91}
# {'_id': ObjectId('5ce737cc869a0fa6b0887547'), 'latitude': -37.6625, 'longitude': 144.287, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('5ce737cc869a0fa6b088754e'), 'latitude': -37.0155, 'longitude': 148.1432, 'confidence': 97, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('5ce737cc869a0fa6b0887550'), 'latitude': -36.7152, 'longitude': 141.3853, 'confidence': 94, 'surface_temperature_celcius': 74}
# {'_id': ObjectId('5ce737cc869a0fa6b088755c'), 'latitude': -34.357, 'longitude': 141.5361, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('5ce737cc869a0fa6b088755d'), 'latitude': -34.3539, 'longitude': 141.5547, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('5ce737cc869a0fa6b088755e'), 'latitude': -36.9939, 'longitude': 148.2244, 'confidence': 90, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('5ce737cc869a0fa6b0887560'), 'latitude': -36.9959, 'longitude': 148.2118, 'confidence': 95, 'surface_temperature_celcius': 75}
# {'_id': ObjectId('5ce737cc869a0fa6b0887561'), 'latitude': -34.3654, 'longitude': 141.543, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('5ce737cc869a0fa6b0887564'), 'latitude': -34.3554, 'longitude': 141.5413, 'confidence': 96, 'surface_temperature_celcius': 79}
# {'_id': ObjectId('5ce737cc869a0fa6b0887565'), 'latitude': -34.3555, 'longitude': 141.5495, 'confidence': 94, 'surface_temperature_celcius': 75}
# {'_id': ObjectId('5ce737cc869a0fa6b0887569'), 'latitude': -37.0193, 'longitude': 148.1459, 'confidence': 84, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('5ce737cc869a0fa6b088756a'), 'latitude': -37.4229, 'longitude': 147.027, 'confidence': 100, 'surface_temperature_celcius': 99}
# {'_id': ObjectId('5ce737cc869a0fa6b088756b'), 'latitude': -37.0055, 'longitude': 148.1582, 'confidence': 80, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('5ce737cc869a0fa6b088756c'), 'latitude': -37.4128, 'longitude': 147.0242, 'confidence': 85, 'surface_temperature_celcius': 98}
# {'_id': ObjectId('5ce737cc869a0fa6b088756f'), 'latitude': -37.2284, 'longitude': 147.9187, 'confidence': 94, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('5ce737cc869a0fa6b0887570'), 'latitude': -37.6572, 'longitude': 142.0703, 'confidence': 97, 'surface_temperature_celcius': 80}

# %% [markdown]
# ### c
# Find date , surface temperature (°C), air temperature (°C), relative humidity and
# max wind speed on 15th and 16th of December 2017.

# %%
def question_d():
    connection = pymongo.MongoClient("localhost", 27017)
    database = connection["fit5148_assignment_db"]

    climate_record = database["climate"]
    date = datetime.datetime.strptime("2017-12-15",'%Y-%m-%d')
    date2 = datetime.datetime.strptime("2017-12-16",'%Y-%m-%d')
    records = climate_record.aggregate([
        {
            "$lookup": {  # join climate_records and hotspot_records
                "from": "hotspot_record",
                "localField": "date",
                "foreignField": "date",
                "as": "hotspot"
            }
        },
        {"$unwind": "$hotspot"},  # unwind in order to do a match
        {
            "$match": {  # 15th and 16th of December 2017
                "$or": [
                    {"date": date},
                    {"date": date2}
                ]
            }
        },
        {
            "$project": {  # project air temperature , surface temperature and confidence
                "hotspot.surface_temperature_celcius": 1,
                "air_temperature_celcius": 1,
                "relative_humidity": 1,
                "max_wind_speed": 1
                
            }
        }

    ])


    for record in records:
        print(record)

    return records


question_d()
# Out:
# {'_id': ObjectId('5ce737cc869a0fa6b08876da'), 'air_temperature_celcius': 18, 'relative_humidity': 52.0, 'max_wind_speed': 14.0, 'hotspot': {'surface_temperature_celcius': 42}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876da'), 'air_temperature_celcius': 18, 'relative_humidity': 52.0, 'max_wind_speed': 14.0, 'hotspot': {'surface_temperature_celcius': 36}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876da'), 'air_temperature_celcius': 18, 'relative_humidity': 52.0, 'max_wind_speed': 14.0, 'hotspot': {'surface_temperature_celcius': 38}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876da'), 'air_temperature_celcius': 18, 'relative_humidity': 52.0, 'max_wind_speed': 14.0, 'hotspot': {'surface_temperature_celcius': 40}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876db'), 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0, 'hotspot': {'surface_temperature_celcius': 43}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876db'), 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0, 'hotspot': {'surface_temperature_celcius': 33}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876db'), 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876db'), 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0, 'hotspot': {'surface_temperature_celcius': 73}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876db'), 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876db'), 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0, 'hotspot': {'surface_temperature_celcius': 75}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876db'), 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876db'), 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0, 'hotspot': {'surface_temperature_celcius': 66}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876db'), 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0, 'hotspot': {'surface_temperature_celcius': 56}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876db'), 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0, 'hotspot': {'surface_temperature_celcius': 60}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876db'), 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0, 'hotspot': {'surface_temperature_celcius': 73}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876db'), 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0, 'hotspot': {'surface_temperature_celcius': 48}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876db'), 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876db'), 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0, 'hotspot': {'surface_temperature_celcius': 64}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876db'), 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0, 'hotspot': {'surface_temperature_celcius': 57}}

# %% [markdown]
# ### d
#
# Find datetime, *air temperature (°C)*, surface temperature (°C) and confidence when the confidence is between 80 and 100.

# %%
import pymongo


def question_d():
    connection = pymongo.MongoClient("localhost", 27017)
    database = connection["fit5148_assignment_db"]

    climate_record = database["climate"]

    records = climate_record.aggregate([
        {
            "$lookup": {  # join climate_records and hotspot_records
                "from": "hotspot_record",
                "localField": "date",
                "foreignField": "date",
                "as": "hotspot"
            }
        },
        {"$unwind": "$hotspot"},  # unwind in order to do a match
        {
            "$match": {  # 80 <= confidence <= 100
                "$and": [
                    {"hotspot.confidence": {"$gte": 80}},
                    {"hotspot.confidence": {"$lte": 100}}
                ]
            }
        },
        {
            "$project": {  # project air temperature , surface temperature and confidence
                "air_temperature_celcius": 1,
                "hotspot.surface_temperature_celcius": 1,
                "hotspots.confidence": 1
            }
        }

    ])


    for record in records:
        print(record)

    return records


question_d()
# Out:
# {'_id': ObjectId('5ce737cc869a0fa6b08875be'), 'air_temperature_celcius': 20, 'hotspot': {'surface_temperature_celcius': 62}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875be'), 'air_temperature_celcius': 20, 'hotspot': {'surface_temperature_celcius': 59}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875bf'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 64}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875c1'), 'air_temperature_celcius': 23, 'hotspot': {'surface_temperature_celcius': 41}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875c2'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 105}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875c2'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 109}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875c2'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 73}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875c2'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 80}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875c2'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875c4'), 'air_temperature_celcius': 21, 'hotspot': {'surface_temperature_celcius': 105}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875c4'), 'air_temperature_celcius': 21, 'hotspot': {'surface_temperature_celcius': 71}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875c4'), 'air_temperature_celcius': 21, 'hotspot': {'surface_temperature_celcius': 99}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875c4'), 'air_temperature_celcius': 21, 'hotspot': {'surface_temperature_celcius': 68}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875c4'), 'air_temperature_celcius': 21, 'hotspot': {'surface_temperature_celcius': 98}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875c6'), 'air_temperature_celcius': 25, 'hotspot': {'surface_temperature_celcius': 67}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875c6'), 'air_temperature_celcius': 25, 'hotspot': {'surface_temperature_celcius': 72}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875c6'), 'air_temperature_celcius': 25, 'hotspot': {'surface_temperature_celcius': 68}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875c6'), 'air_temperature_celcius': 25, 'hotspot': {'surface_temperature_celcius': 75}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875c6'), 'air_temperature_celcius': 25, 'hotspot': {'surface_temperature_celcius': 65}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875c6'), 'air_temperature_celcius': 25, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875c6'), 'air_temperature_celcius': 25, 'hotspot': {'surface_temperature_celcius': 79}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875c6'), 'air_temperature_celcius': 25, 'hotspot': {'surface_temperature_celcius': 75}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875c9'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 74}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875c9'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 59}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875c9'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 60}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875ca'), 'air_temperature_celcius': 21, 'hotspot': {'surface_temperature_celcius': 121}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875ca'), 'air_temperature_celcius': 21, 'hotspot': {'surface_temperature_celcius': 80}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875cb'), 'air_temperature_celcius': 24, 'hotspot': {'surface_temperature_celcius': 60}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875cb'), 'air_temperature_celcius': 24, 'hotspot': {'surface_temperature_celcius': 79}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875cb'), 'air_temperature_celcius': 24, 'hotspot': {'surface_temperature_celcius': 66}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875cb'), 'air_temperature_celcius': 24, 'hotspot': {'surface_temperature_celcius': 83}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875cb'), 'air_temperature_celcius': 24, 'hotspot': {'surface_temperature_celcius': 91}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875cb'), 'air_temperature_celcius': 24, 'hotspot': {'surface_temperature_celcius': 58}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875cb'), 'air_temperature_celcius': 24, 'hotspot': {'surface_temperature_celcius': 113}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875cb'), 'air_temperature_celcius': 24, 'hotspot': {'surface_temperature_celcius': 70}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875cb'), 'air_temperature_celcius': 24, 'hotspot': {'surface_temperature_celcius': 106}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d1'), 'air_temperature_celcius': 23, 'hotspot': {'surface_temperature_celcius': 65}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d1'), 'air_temperature_celcius': 23, 'hotspot': {'surface_temperature_celcius': 62}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d1'), 'air_temperature_celcius': 23, 'hotspot': {'surface_temperature_celcius': 75}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d1'), 'air_temperature_celcius': 23, 'hotspot': {'surface_temperature_celcius': 59}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d1'), 'air_temperature_celcius': 23, 'hotspot': {'surface_temperature_celcius': 111}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d1'), 'air_temperature_celcius': 23, 'hotspot': {'surface_temperature_celcius': 77}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d1'), 'air_temperature_celcius': 23, 'hotspot': {'surface_temperature_celcius': 99}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d2'), 'air_temperature_celcius': 23, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d2'), 'air_temperature_celcius': 23, 'hotspot': {'surface_temperature_celcius': 53}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d2'), 'air_temperature_celcius': 23, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d2'), 'air_temperature_celcius': 23, 'hotspot': {'surface_temperature_celcius': 68}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d2'), 'air_temperature_celcius': 23, 'hotspot': {'surface_temperature_celcius': 70}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d2'), 'air_temperature_celcius': 23, 'hotspot': {'surface_temperature_celcius': 89}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d2'), 'air_temperature_celcius': 23, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d2'), 'air_temperature_celcius': 23, 'hotspot': {'surface_temperature_celcius': 62}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d2'), 'air_temperature_celcius': 23, 'hotspot': {'surface_temperature_celcius': 58}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 64}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 60}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 71}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 76}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 73}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 56}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 74}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 82}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 80}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 63}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 62}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 80}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 107}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 108}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 86}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 53}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 57}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 90}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 62}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 81}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 59}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 63}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 62}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 58}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 81}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 57}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d4'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 60}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d7'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d7'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 62}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d7'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 56}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d7'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 53}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d7'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 61}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875d7'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 43}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 40}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 62}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 45}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 96}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 72}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 64}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 77}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 78}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 93}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 59}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 58}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 90}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 115}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 61}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 98}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 89}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 59}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 63}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 66}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 62}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 82}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 53}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 103}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 97}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 66}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 61}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 86}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 72}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 76}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 60}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 65}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 65}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875da'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 44}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 64}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 63}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 62}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 64}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 61}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 120}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 67}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 66}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 66}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 107}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 64}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 63}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 62}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 76}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 95}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 57}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 65}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 78}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 66}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 57}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 81}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 113}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 58}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 59}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 62}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 62}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 79}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 61}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 82}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 61}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 58}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 123}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 118}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 78}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 72}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 120}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 92}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 101}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 98}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875db'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 53}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 58}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 39}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 44}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 47}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 40}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 49}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 45}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 39}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 42}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 39}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 88}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 83}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 72}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 76}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 65}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 62}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 66}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 56}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 65}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 64}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 76}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 92}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 63}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dc'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 64}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 45}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 65}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 69}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 95}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 88}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 97}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 60}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 76}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 99}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 57}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 64}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 65}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 65}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 64}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 70}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 85}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 72}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 65}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 62}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 60}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 56}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 71}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 60}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 103}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 69}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 68}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 59}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 67}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 66}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 96}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 115}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 58}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 95}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 65}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 63}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 60}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 78}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 77}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 68}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 81}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 56}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 104}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 71}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 62}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 61}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 53}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 60}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 67}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 62}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 86}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 57}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 62}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 100}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 72}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 57}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875dd'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 89}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875de'), 'air_temperature_celcius': 21, 'hotspot': {'surface_temperature_celcius': 41}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875de'), 'air_temperature_celcius': 21, 'hotspot': {'surface_temperature_celcius': 39}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875de'), 'air_temperature_celcius': 21, 'hotspot': {'surface_temperature_celcius': 49}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875de'), 'air_temperature_celcius': 21, 'hotspot': {'surface_temperature_celcius': 41}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875de'), 'air_temperature_celcius': 21, 'hotspot': {'surface_temperature_celcius': 41}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875de'), 'air_temperature_celcius': 21, 'hotspot': {'surface_temperature_celcius': 45}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875de'), 'air_temperature_celcius': 21, 'hotspot': {'surface_temperature_celcius': 49}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875de'), 'air_temperature_celcius': 21, 'hotspot': {'surface_temperature_celcius': 43}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875de'), 'air_temperature_celcius': 21, 'hotspot': {'surface_temperature_celcius': 42}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875de'), 'air_temperature_celcius': 21, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875de'), 'air_temperature_celcius': 21, 'hotspot': {'surface_temperature_celcius': 53}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875de'), 'air_temperature_celcius': 21, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875de'), 'air_temperature_celcius': 21, 'hotspot': {'surface_temperature_celcius': 89}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875de'), 'air_temperature_celcius': 21, 'hotspot': {'surface_temperature_celcius': 78}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875de'), 'air_temperature_celcius': 21, 'hotspot': {'surface_temperature_celcius': 70}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875de'), 'air_temperature_celcius': 21, 'hotspot': {'surface_temperature_celcius': 70}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875de'), 'air_temperature_celcius': 21, 'hotspot': {'surface_temperature_celcius': 76}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875de'), 'air_temperature_celcius': 21, 'hotspot': {'surface_temperature_celcius': 106}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875df'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 85}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875df'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 69}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875df'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 94}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875df'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 59}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875df'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 83}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875df'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 66}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875df'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875df'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 53}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875df'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 58}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e2'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e2'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 58}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e2'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 60}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e3'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 43}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e3'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 106}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e3'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 58}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e3'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 75}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e3'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 98}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e3'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 77}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e3'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 63}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e3'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 75}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e3'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 61}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e3'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 70}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e3'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 58}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e3'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 58}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e3'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 106}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e3'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 56}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e3'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 57}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e3'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 59}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e3'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 98}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e3'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 63}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e3'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 71}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e3'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e3'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 73}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e3'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 111}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 78}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 72}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 97}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 60}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 70}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 65}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 53}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 64}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 59}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 60}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 89}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 73}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 88}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 58}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 69}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 85}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 66}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 96}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 66}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 80}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 63}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 82}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 65}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 64}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 66}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 61}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 56}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 64}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 93}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 95}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 65}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 114}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 58}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 67}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 71}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 120}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 90}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 102}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 53}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 77}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 66}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 72}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 58}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 82}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 66}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 70}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 88}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 113}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 60}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 95}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 67}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 92}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 64}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 80}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 71}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 101}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 107}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 75}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 115}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 89}}
# {'_id': ObjectId('5ce737cc869a0fa6b08875e4'), 'air_temperature_celcius': 16, 'hotspot': {'surface_temperature_celcius': 68}}
# ...
# {'_id': ObjectId('5ce737cc869a0fa6b0887684'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 112}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887684'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 60}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887687'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 56}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887687'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 56}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887687'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 65}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887687'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 48}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887687'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 52}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887687'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 50}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887687'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 84}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887687'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 79}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887687'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 60}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887687'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 60}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887687'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 50}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887688'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 65}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887688'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 41}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887688'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 61}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887688'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 43}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887688'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 61}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887688'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 47}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887688'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 38}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887688'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 48}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887688'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 48}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887688'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 50}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887688'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 88}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887688'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 76}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887688'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 52}}
# {'_id': ObjectId('5ce737cc869a0fa6b088768b'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 56}}
# {'_id': ObjectId('5ce737cc869a0fa6b088768b'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 60}}
# {'_id': ObjectId('5ce737cc869a0fa6b088768d'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 49}}
# {'_id': ObjectId('5ce737cc869a0fa6b088768f'), 'air_temperature_celcius': 12, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b088768f'), 'air_temperature_celcius': 12, 'hotspot': {'surface_temperature_celcius': 52}}
# {'_id': ObjectId('5ce737cc869a0fa6b088768f'), 'air_temperature_celcius': 12, 'hotspot': {'surface_temperature_celcius': 61}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887690'), 'air_temperature_celcius': 11, 'hotspot': {'surface_temperature_celcius': 50}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887690'), 'air_temperature_celcius': 11, 'hotspot': {'surface_temperature_celcius': 61}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887691'), 'air_temperature_celcius': 13, 'hotspot': {'surface_temperature_celcius': 42}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887691'), 'air_temperature_celcius': 13, 'hotspot': {'surface_temperature_celcius': 63}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887691'), 'air_temperature_celcius': 13, 'hotspot': {'surface_temperature_celcius': 48}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887691'), 'air_temperature_celcius': 13, 'hotspot': {'surface_temperature_celcius': 49}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887691'), 'air_temperature_celcius': 13, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887691'), 'air_temperature_celcius': 13, 'hotspot': {'surface_temperature_celcius': 63}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887691'), 'air_temperature_celcius': 13, 'hotspot': {'surface_temperature_celcius': 90}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887691'), 'air_temperature_celcius': 13, 'hotspot': {'surface_temperature_celcius': 65}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887691'), 'air_temperature_celcius': 13, 'hotspot': {'surface_temperature_celcius': 59}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887692'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 46}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887692'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 46}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887692'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887692'), 'air_temperature_celcius': 19, 'hotspot': {'surface_temperature_celcius': 58}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887695'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 42}}
# {'_id': ObjectId('5ce737cc869a0fa6b0887698'), 'air_temperature_celcius': 13, 'hotspot': {'surface_temperature_celcius': 77}}
# {'_id': ObjectId('5ce737cc869a0fa6b088769d'), 'air_temperature_celcius': 13, 'hotspot': {'surface_temperature_celcius': 87}}
# {'_id': ObjectId('5ce737cc869a0fa6b088769d'), 'air_temperature_celcius': 13, 'hotspot': {'surface_temperature_celcius': 85}}
# {'_id': ObjectId('5ce737cc869a0fa6b088769f'), 'air_temperature_celcius': 22, 'hotspot': {'surface_temperature_celcius': 43}}
# {'_id': ObjectId('5ce737cc869a0fa6b088769f'), 'air_temperature_celcius': 22, 'hotspot': {'surface_temperature_celcius': 68}}
# {'_id': ObjectId('5ce737cc869a0fa6b088769f'), 'air_temperature_celcius': 22, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876a0'), 'air_temperature_celcius': 26, 'hotspot': {'surface_temperature_celcius': 59}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876a0'), 'air_temperature_celcius': 26, 'hotspot': {'surface_temperature_celcius': 56}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876a2'), 'air_temperature_celcius': 13, 'hotspot': {'surface_temperature_celcius': 46}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876a2'), 'air_temperature_celcius': 13, 'hotspot': {'surface_temperature_celcius': 50}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876a3'), 'air_temperature_celcius': 12, 'hotspot': {'surface_temperature_celcius': 59}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876a3'), 'air_temperature_celcius': 12, 'hotspot': {'surface_temperature_celcius': 67}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876a8'), 'air_temperature_celcius': 13, 'hotspot': {'surface_temperature_celcius': 48}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876a8'), 'air_temperature_celcius': 13, 'hotspot': {'surface_temperature_celcius': 53}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876a9'), 'air_temperature_celcius': 22, 'hotspot': {'surface_temperature_celcius': 60}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876aa'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 56}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876b2'), 'air_temperature_celcius': 13, 'hotspot': {'surface_temperature_celcius': 58}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876b2'), 'air_temperature_celcius': 13, 'hotspot': {'surface_temperature_celcius': 65}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876b2'), 'air_temperature_celcius': 13, 'hotspot': {'surface_temperature_celcius': 62}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876b6'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 59}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876b6'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 93}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876b6'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 77}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876b6'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 62}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876b6'), 'air_temperature_celcius': 14, 'hotspot': {'surface_temperature_celcius': 80}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876b8'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 37}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876b8'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 59}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876b8'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 60}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876b9'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 69}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876ba'), 'air_temperature_celcius': 24, 'hotspot': {'surface_temperature_celcius': 61}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876ba'), 'air_temperature_celcius': 24, 'hotspot': {'surface_temperature_celcius': 53}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876bb'), 'air_temperature_celcius': 28, 'hotspot': {'surface_temperature_celcius': 65}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876c2'), 'air_temperature_celcius': 24, 'hotspot': {'surface_temperature_celcius': 59}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876c3'), 'air_temperature_celcius': 23, 'hotspot': {'surface_temperature_celcius': 59}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876c3'), 'air_temperature_celcius': 23, 'hotspot': {'surface_temperature_celcius': 64}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876c4'), 'air_temperature_celcius': 24, 'hotspot': {'surface_temperature_celcius': 60}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876c4'), 'air_temperature_celcius': 24, 'hotspot': {'surface_temperature_celcius': 73}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876ca'), 'air_temperature_celcius': 28, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876ca'), 'air_temperature_celcius': 28, 'hotspot': {'surface_temperature_celcius': 87}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876ca'), 'air_temperature_celcius': 28, 'hotspot': {'surface_temperature_celcius': 80}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876ca'), 'air_temperature_celcius': 28, 'hotspot': {'surface_temperature_celcius': 84}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876cb'), 'air_temperature_celcius': 26, 'hotspot': {'surface_temperature_celcius': 53}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876cb'), 'air_temperature_celcius': 26, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876cb'), 'air_temperature_celcius': 26, 'hotspot': {'surface_temperature_celcius': 49}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876cb'), 'air_temperature_celcius': 26, 'hotspot': {'surface_temperature_celcius': 38}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876cb'), 'air_temperature_celcius': 26, 'hotspot': {'surface_temperature_celcius': 42}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876cb'), 'air_temperature_celcius': 26, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876cb'), 'air_temperature_celcius': 26, 'hotspot': {'surface_temperature_celcius': 65}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876cb'), 'air_temperature_celcius': 26, 'hotspot': {'surface_temperature_celcius': 71}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876cb'), 'air_temperature_celcius': 26, 'hotspot': {'surface_temperature_celcius': 59}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876cb'), 'air_temperature_celcius': 26, 'hotspot': {'surface_temperature_celcius': 83}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876cb'), 'air_temperature_celcius': 26, 'hotspot': {'surface_temperature_celcius': 57}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876cb'), 'air_temperature_celcius': 26, 'hotspot': {'surface_temperature_celcius': 61}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876cb'), 'air_temperature_celcius': 26, 'hotspot': {'surface_temperature_celcius': 86}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876cb'), 'air_temperature_celcius': 26, 'hotspot': {'surface_temperature_celcius': 58}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876cb'), 'air_temperature_celcius': 26, 'hotspot': {'surface_temperature_celcius': 63}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876cb'), 'air_temperature_celcius': 26, 'hotspot': {'surface_temperature_celcius': 76}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876cb'), 'air_temperature_celcius': 26, 'hotspot': {'surface_temperature_celcius': 56}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876cb'), 'air_temperature_celcius': 26, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876d3'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876d3'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 71}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876d3'), 'air_temperature_celcius': 15, 'hotspot': {'surface_temperature_celcius': 52}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876d4'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 61}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876d4'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876d4'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 58}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876d4'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 60}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876d8'), 'air_temperature_celcius': 28, 'hotspot': {'surface_temperature_celcius': 60}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876d9'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 70}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876da'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 42}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876db'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 43}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876db'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 73}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876db'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876db'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 75}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876db'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 66}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876db'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 73}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876db'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 55}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876db'), 'air_temperature_celcius': 18, 'hotspot': {'surface_temperature_celcius': 64}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876e4'), 'air_temperature_celcius': 17, 'hotspot': {'surface_temperature_celcius': 54}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876e6'), 'air_temperature_celcius': 28, 'hotspot': {'surface_temperature_celcius': 63}}
# {'_id': ObjectId('5ce737cc869a0fa6b08876e6'), 'air_temperature_celcius': 28, 'hotspot': {'surface_temperature_celcius': 67}}

# %% [markdown]
# ### e
# Find the top 10 records with the highest surface temperature (°C).

# %%
import pymongo


def question_e():
    connection = pymongo.MongoClient("localhost", 27017)
    database = connection["fit5148_assignment_db"]
    hotspot = database["hotspot_record"]

    records = hotspot.find().sort("surface_temperature_celcius", direction=pymongo.DESCENDING).limit(10)

    for record in records:
        print(record)

    return records


question_e()
# Out:
# {'_id': ObjectId('5ce737cc869a0fa6b0886fb4'), 'latitude': -38.1665, 'longitude': 143.062, 'datetime': datetime.datetime(2017, 4, 18, 4, 52), 'confidence': 100, 'date': datetime.datetime(2017, 4, 18, 0, 0), 'surface_temperature_celcius': 124}
# {'_id': ObjectId('5ce737cc869a0fa6b088745e'), 'latitude': -36.343, 'longitude': 142.1986, 'datetime': datetime.datetime(2017, 4, 4, 4, 32, 50), 'confidence': 100, 'date': datetime.datetime(2017, 4, 4, 0, 0), 'surface_temperature_celcius': 123}
# {'_id': ObjectId('5ce737cc869a0fa6b0886f26'), 'latitude': -36.9318, 'longitude': 143.0907, 'datetime': datetime.datetime(2017, 5, 1, 4, 14, 20), 'confidence': 100, 'date': datetime.datetime(2017, 5, 1, 0, 0), 'surface_temperature_celcius': 122}
# {'_id': ObjectId('5ce737cc869a0fa6b088754d'), 'latitude': -37.017, 'longitude': 148.1297, 'datetime': datetime.datetime(2017, 3, 18, 3, 50, 50), 'confidence': 100, 'date': datetime.datetime(2017, 3, 18, 0, 0), 'surface_temperature_celcius': 121}
# {'_id': ObjectId('5ce737cc869a0fa6b0886d38'), 'latitude': -34.9938, 'longitude': 141.876, 'datetime': datetime.datetime(2017, 5, 13, 4, 40, 20), 'confidence': 100, 'date': datetime.datetime(2017, 5, 13, 0, 0), 'surface_temperature_celcius': 120}
# {'_id': ObjectId('5ce737cc869a0fa6b088704d'), 'latitude': -37.8326, 'longitude': 143.4999, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50), 'confidence': 100, 'date': datetime.datetime(2017, 4, 18, 0, 0), 'surface_temperature_celcius': 120}
# {'_id': ObjectId('5ce737cc869a0fa6b08871d0'), 'latitude': -37.0745, 'longitude': 141.0692, 'datetime': datetime.datetime(2017, 4, 13, 4, 28, 10), 'confidence': 100, 'date': datetime.datetime(2017, 4, 13, 0, 0), 'surface_temperature_celcius': 120}
# {'_id': ObjectId('5ce737cc869a0fa6b0887425'), 'latitude': -36.1057, 'longitude': 141.7608, 'datetime': datetime.datetime(2017, 4, 4, 4, 40), 'confidence': 100, 'date': datetime.datetime(2017, 4, 4, 0, 0), 'surface_temperature_celcius': 120}
# {'_id': ObjectId('5ce737cc869a0fa6b0887465'), 'latitude': -36.3521, 'longitude': 142.2008, 'datetime': datetime.datetime(2017, 4, 4, 4, 32, 40), 'confidence': 100, 'date': datetime.datetime(2017, 4, 4, 0, 0), 'surface_temperature_celcius': 120}
# {'_id': ObjectId('5ce737cc869a0fa6b0886e7c'), 'latitude': -36.4057, 'longitude': 140.9806, 'datetime': datetime.datetime(2017, 5, 4, 4, 44, 50), 'confidence': 100, 'date': datetime.datetime(2017, 5, 4, 0, 0), 'surface_temperature_celcius': 119}

# %% [markdown]
# ### f
# Find the number of fire in each day. You are required to only display the
# total number of fire and the date in the output.

# %%
import pymongo


def question_f():
    connection = pymongo.MongoClient("localhost", 27017)
    database = connection["fit5148_assignment_db"]
    hotspot = database["hotspot_record"]

    records = hotspot.aggregate([
        {"$group": {"_id": "$date", "count": {"$sum": 1}}},
        {"$sort": {"count": -1}}
    ])

    for record in records:
        print(record)

    return records


question_f()
# Out:
# {'_id': datetime.datetime(2017, 4, 13, 0, 0), 'count': 357}
# {'_id': datetime.datetime(2017, 4, 18, 0, 0), 'count': 325}
# {'_id': datetime.datetime(2017, 5, 4, 0, 0), 'count': 135}
# {'_id': datetime.datetime(2017, 4, 6, 0, 0), 'count': 118}
# {'_id': datetime.datetime(2017, 5, 10, 0, 0), 'count': 114}
# {'_id': datetime.datetime(2017, 5, 15, 0, 0), 'count': 102}
# {'_id': datetime.datetime(2017, 4, 4, 0, 0), 'count': 89}
# {'_id': datetime.datetime(2017, 4, 3, 0, 0), 'count': 72}
# {'_id': datetime.datetime(2017, 4, 12, 0, 0), 'count': 69}
# {'_id': datetime.datetime(2017, 4, 15, 0, 0), 'count': 69}
# {'_id': datetime.datetime(2017, 5, 3, 0, 0), 'count': 64}
# {'_id': datetime.datetime(2017, 3, 28, 0, 0), 'count': 54}
# {'_id': datetime.datetime(2017, 5, 13, 0, 0), 'count': 54}
# {'_id': datetime.datetime(2017, 4, 19, 0, 0), 'count': 50}
# {'_id': datetime.datetime(2017, 4, 5, 0, 0), 'count': 49}
# {'_id': datetime.datetime(2017, 4, 7, 0, 0), 'count': 39}
# {'_id': datetime.datetime(2017, 4, 17, 0, 0), 'count': 38}
# {'_id': datetime.datetime(2017, 5, 22, 0, 0), 'count': 33}
# {'_id': datetime.datetime(2017, 5, 5, 0, 0), 'count': 31}
# {'_id': datetime.datetime(2017, 4, 20, 0, 0), 'count': 31}
# {'_id': datetime.datetime(2017, 11, 30, 0, 0), 'count': 31}
# {'_id': datetime.datetime(2017, 9, 24, 0, 0), 'count': 28}
# {'_id': datetime.datetime(2017, 4, 11, 0, 0), 'count': 24}
# {'_id': datetime.datetime(2017, 5, 8, 0, 0), 'count': 24}
# {'_id': datetime.datetime(2017, 9, 23, 0, 0), 'count': 23}
# {'_id': datetime.datetime(2017, 3, 31, 0, 0), 'count': 22}
# {'_id': datetime.datetime(2017, 3, 19, 0, 0), 'count': 21}
# {'_id': datetime.datetime(2017, 5, 1, 0, 0), 'count': 20}
# {'_id': datetime.datetime(2017, 4, 8, 0, 0), 'count': 20}
# {'_id': datetime.datetime(2017, 4, 23, 0, 0), 'count': 19}
# {'_id': datetime.datetime(2017, 5, 11, 0, 0), 'count': 19}
# {'_id': datetime.datetime(2017, 10, 3, 0, 0), 'count': 18}
# {'_id': datetime.datetime(2017, 4, 14, 0, 0), 'count': 18}
# {'_id': datetime.datetime(2017, 4, 16, 0, 0), 'count': 18}
# {'_id': datetime.datetime(2017, 3, 26, 0, 0), 'count': 17}
# {'_id': datetime.datetime(2017, 5, 6, 0, 0), 'count': 17}
# {'_id': datetime.datetime(2017, 12, 16, 0, 0), 'count': 15}
# {'_id': datetime.datetime(2017, 6, 7, 0, 0), 'count': 14}
# {'_id': datetime.datetime(2017, 5, 9, 0, 0), 'count': 13}
# {'_id': datetime.datetime(2017, 3, 25, 0, 0), 'count': 13}
# {'_id': datetime.datetime(2017, 6, 2, 0, 0), 'count': 11}
# {'_id': datetime.datetime(2017, 11, 9, 0, 0), 'count': 10}
# {'_id': datetime.datetime(2017, 3, 14, 0, 0), 'count': 10}
# {'_id': datetime.datetime(2017, 5, 12, 0, 0), 'count': 10}
# {'_id': datetime.datetime(2017, 5, 2, 0, 0), 'count': 10}
# {'_id': datetime.datetime(2017, 6, 4, 0, 0), 'count': 9}
# {'_id': datetime.datetime(2017, 8, 13, 0, 0), 'count': 9}
# {'_id': datetime.datetime(2017, 3, 10, 0, 0), 'count': 8}
# {'_id': datetime.datetime(2017, 4, 24, 0, 0), 'count': 8}
# {'_id': datetime.datetime(2017, 7, 2, 0, 0), 'count': 8}
# {'_id': datetime.datetime(2017, 10, 1, 0, 0), 'count': 8}
# {'_id': datetime.datetime(2017, 11, 29, 0, 0), 'count': 8}
# {'_id': datetime.datetime(2017, 3, 15, 0, 0), 'count': 7}
# {'_id': datetime.datetime(2017, 4, 1, 0, 0), 'count': 7}
# {'_id': datetime.datetime(2017, 10, 2, 0, 0), 'count': 7}
# {'_id': datetime.datetime(2017, 5, 18, 0, 0), 'count': 7}
# {'_id': datetime.datetime(2017, 9, 27, 0, 0), 'count': 7}
# {'_id': datetime.datetime(2017, 10, 18, 0, 0), 'count': 6}
# {'_id': datetime.datetime(2017, 3, 17, 0, 0), 'count': 6}
# {'_id': datetime.datetime(2017, 6, 20, 0, 0), 'count': 6}
# {'_id': datetime.datetime(2017, 6, 30, 0, 0), 'count': 6}
# {'_id': datetime.datetime(2017, 4, 2, 0, 0), 'count': 5}
# {'_id': datetime.datetime(2017, 5, 23, 0, 0), 'count': 5}
# {'_id': datetime.datetime(2017, 9, 20, 0, 0), 'count': 5}
# {'_id': datetime.datetime(2017, 8, 14, 0, 0), 'count': 5}
# {'_id': datetime.datetime(2017, 3, 12, 0, 0), 'count': 5}
# {'_id': datetime.datetime(2017, 10, 4, 0, 0), 'count': 5}
# {'_id': datetime.datetime(2017, 11, 13, 0, 0), 'count': 5}
# {'_id': datetime.datetime(2017, 10, 17, 0, 0), 'count': 5}
# {'_id': datetime.datetime(2017, 10, 26, 0, 0), 'count': 5}
# {'_id': datetime.datetime(2017, 11, 23, 0, 0), 'count': 5}
# {'_id': datetime.datetime(2017, 10, 27, 0, 0), 'count': 5}
# {'_id': datetime.datetime(2017, 11, 12, 0, 0), 'count': 5}
# {'_id': datetime.datetime(2017, 12, 8, 0, 0), 'count': 5}
# {'_id': datetime.datetime(2017, 6, 14, 0, 0), 'count': 4}
# {'_id': datetime.datetime(2017, 5, 26, 0, 0), 'count': 4}
# {'_id': datetime.datetime(2017, 7, 1, 0, 0), 'count': 4}
# {'_id': datetime.datetime(2017, 9, 10, 0, 0), 'count': 4}
# {'_id': datetime.datetime(2017, 12, 15, 0, 0), 'count': 4}
# {'_id': datetime.datetime(2017, 10, 21, 0, 0), 'count': 4}
# {'_id': datetime.datetime(2017, 12, 27, 0, 0), 'count': 4}
# {'_id': datetime.datetime(2017, 11, 11, 0, 0), 'count': 4}
# {'_id': datetime.datetime(2017, 11, 5, 0, 0), 'count': 4}
# {'_id': datetime.datetime(2017, 12, 9, 0, 0), 'count': 4}
# {'_id': datetime.datetime(2017, 3, 18, 0, 0), 'count': 3}
# {'_id': datetime.datetime(2017, 4, 25, 0, 0), 'count': 3}
# {'_id': datetime.datetime(2017, 4, 29, 0, 0), 'count': 3}
# {'_id': datetime.datetime(2017, 6, 9, 0, 0), 'count': 3}
# {'_id': datetime.datetime(2017, 3, 9, 0, 0), 'count': 3}
# {'_id': datetime.datetime(2017, 7, 6, 0, 0), 'count': 3}
# {'_id': datetime.datetime(2017, 5, 7, 0, 0), 'count': 3}
# {'_id': datetime.datetime(2017, 10, 20, 0, 0), 'count': 3}
# {'_id': datetime.datetime(2017, 10, 15, 0, 0), 'count': 3}
# {'_id': datetime.datetime(2017, 5, 16, 0, 0), 'count': 3}
# {'_id': datetime.datetime(2017, 5, 24, 0, 0), 'count': 3}
# {'_id': datetime.datetime(2017, 10, 10, 0, 0), 'count': 3}
# {'_id': datetime.datetime(2017, 11, 14, 0, 0), 'count': 3}
# {'_id': datetime.datetime(2017, 3, 24, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2017, 4, 22, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2017, 6, 3, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2017, 6, 11, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2017, 6, 16, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2017, 6, 18, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2017, 8, 2, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2017, 9, 21, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2017, 7, 31, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2017, 9, 29, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2017, 7, 29, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2017, 11, 8, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2017, 3, 8, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2017, 8, 1, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2017, 11, 22, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2017, 12, 10, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2017, 6, 1, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2017, 3, 6, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2017, 3, 13, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2017, 10, 6, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2017, 7, 14, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2017, 3, 29, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2017, 5, 17, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2017, 5, 14, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2017, 6, 22, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2017, 7, 4, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2017, 7, 5, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2017, 8, 10, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2017, 3, 7, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2017, 9, 22, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2017, 9, 26, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2017, 8, 5, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2017, 10, 9, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2017, 10, 8, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2017, 10, 7, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2017, 10, 23, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2017, 12, 12, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2017, 10, 28, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2017, 6, 13, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2017, 10, 16, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2017, 11, 21, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2017, 11, 28, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2017, 12, 14, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2017, 12, 21, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2017, 4, 26, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2017, 12, 24, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2017, 12, 25, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2017, 12, 13, 0, 0), 'count': 1}

# %% [markdown]
# ### g
# Find the average surface temperature (°C) for each day . You are required to only display average surface temperature (°C) and the date in the output.

# %%
import pymongo


def question_g():
    connection = pymongo.MongoClient("localhost", 27017)
    database = connection["fit5148_assignment_db"]
    hotspot = database["hotspot_record"]

    records = hotspot.aggregate([
        {"$group": {"_id": "$date", "average_surface_temperature": {"$avg": "$surface_temperature_celcius"}}},
        {"$sort": {"average_surface_temperature": -1}}
    ])

    for record in records:
        print(record)

    return records


question_g()
# Out:
# {'_id': datetime.datetime(2017, 3, 12, 0, 0), 'average_surface_temperature': 88.2}
# {'_id': datetime.datetime(2017, 3, 18, 0, 0), 'average_surface_temperature': 79.33333333333333}
# {'_id': datetime.datetime(2017, 10, 15, 0, 0), 'average_surface_temperature': 72.66666666666667}
# {'_id': datetime.datetime(2017, 6, 20, 0, 0), 'average_surface_temperature': 71.16666666666667}
# {'_id': datetime.datetime(2017, 12, 14, 0, 0), 'average_surface_temperature': 70.0}
# {'_id': datetime.datetime(2017, 3, 10, 0, 0), 'average_surface_temperature': 69.375}
# {'_id': datetime.datetime(2017, 5, 1, 0, 0), 'average_surface_temperature': 68.4}
# {'_id': datetime.datetime(2017, 3, 25, 0, 0), 'average_surface_temperature': 66.0}
# {'_id': datetime.datetime(2017, 3, 14, 0, 0), 'average_surface_temperature': 65.6}
# {'_id': datetime.datetime(2017, 3, 19, 0, 0), 'average_surface_temperature': 65.57142857142857}
# {'_id': datetime.datetime(2017, 3, 7, 0, 0), 'average_surface_temperature': 64.0}
# {'_id': datetime.datetime(2017, 9, 20, 0, 0), 'average_surface_temperature': 63.6}
# {'_id': datetime.datetime(2017, 8, 2, 0, 0), 'average_surface_temperature': 63.5}
# {'_id': datetime.datetime(2017, 4, 29, 0, 0), 'average_surface_temperature': 63.0}
# {'_id': datetime.datetime(2017, 8, 10, 0, 0), 'average_surface_temperature': 63.0}
# {'_id': datetime.datetime(2017, 12, 27, 0, 0), 'average_surface_temperature': 62.75}
# {'_id': datetime.datetime(2017, 4, 4, 0, 0), 'average_surface_temperature': 62.57303370786517}
# {'_id': datetime.datetime(2017, 4, 14, 0, 0), 'average_surface_temperature': 61.94444444444444}
# {'_id': datetime.datetime(2017, 4, 6, 0, 0), 'average_surface_temperature': 61.71186440677966}
# {'_id': datetime.datetime(2017, 11, 22, 0, 0), 'average_surface_temperature': 61.5}
# {'_id': datetime.datetime(2017, 11, 9, 0, 0), 'average_surface_temperature': 61.3}
# {'_id': datetime.datetime(2017, 3, 28, 0, 0), 'average_surface_temperature': 60.925925925925924}
# {'_id': datetime.datetime(2017, 4, 8, 0, 0), 'average_surface_temperature': 60.75}
# {'_id': datetime.datetime(2017, 11, 29, 0, 0), 'average_surface_temperature': 60.625}
# {'_id': datetime.datetime(2017, 3, 6, 0, 0), 'average_surface_temperature': 60.5}
# {'_id': datetime.datetime(2017, 12, 13, 0, 0), 'average_surface_temperature': 60.0}
# {'_id': datetime.datetime(2017, 4, 15, 0, 0), 'average_surface_temperature': 59.57971014492754}
# {'_id': datetime.datetime(2017, 3, 17, 0, 0), 'average_surface_temperature': 59.5}
# {'_id': datetime.datetime(2017, 4, 24, 0, 0), 'average_surface_temperature': 59.375}
# {'_id': datetime.datetime(2017, 5, 11, 0, 0), 'average_surface_temperature': 59.36842105263158}
# {'_id': datetime.datetime(2017, 11, 21, 0, 0), 'average_surface_temperature': 59.0}
# {'_id': datetime.datetime(2017, 11, 23, 0, 0), 'average_surface_temperature': 58.8}
# {'_id': datetime.datetime(2017, 5, 13, 0, 0), 'average_surface_temperature': 58.611111111111114}
# {'_id': datetime.datetime(2017, 4, 13, 0, 0), 'average_surface_temperature': 58.57983193277311}
# {'_id': datetime.datetime(2017, 11, 5, 0, 0), 'average_surface_temperature': 58.5}
# {'_id': datetime.datetime(2017, 4, 3, 0, 0), 'average_surface_temperature': 58.44444444444444}
# {'_id': datetime.datetime(2017, 12, 9, 0, 0), 'average_surface_temperature': 58.25}
# {'_id': datetime.datetime(2017, 8, 1, 0, 0), 'average_surface_temperature': 58.0}
# {'_id': datetime.datetime(2017, 12, 16, 0, 0), 'average_surface_temperature': 57.8}
# {'_id': datetime.datetime(2017, 5, 6, 0, 0), 'average_surface_temperature': 57.529411764705884}
# {'_id': datetime.datetime(2017, 3, 26, 0, 0), 'average_surface_temperature': 56.88235294117647}
# {'_id': datetime.datetime(2017, 5, 4, 0, 0), 'average_surface_temperature': 56.80740740740741}
# {'_id': datetime.datetime(2017, 5, 3, 0, 0), 'average_surface_temperature': 56.796875}
# {'_id': datetime.datetime(2017, 4, 20, 0, 0), 'average_surface_temperature': 56.58064516129032}
# {'_id': datetime.datetime(2017, 9, 10, 0, 0), 'average_surface_temperature': 56.5}
# {'_id': datetime.datetime(2017, 5, 8, 0, 0), 'average_surface_temperature': 56.291666666666664}
# {'_id': datetime.datetime(2017, 7, 6, 0, 0), 'average_surface_temperature': 56.0}
# {'_id': datetime.datetime(2017, 10, 28, 0, 0), 'average_surface_temperature': 56.0}
# {'_id': datetime.datetime(2017, 5, 2, 0, 0), 'average_surface_temperature': 55.6}
# {'_id': datetime.datetime(2017, 4, 22, 0, 0), 'average_surface_temperature': 54.5}
# {'_id': datetime.datetime(2017, 5, 22, 0, 0), 'average_surface_temperature': 54.484848484848484}
# {'_id': datetime.datetime(2017, 4, 19, 0, 0), 'average_surface_temperature': 54.16}
# {'_id': datetime.datetime(2017, 6, 1, 0, 0), 'average_surface_temperature': 54.0}
# {'_id': datetime.datetime(2017, 12, 25, 0, 0), 'average_surface_temperature': 54.0}
# {'_id': datetime.datetime(2017, 5, 15, 0, 0), 'average_surface_temperature': 53.950980392156865}
# {'_id': datetime.datetime(2017, 4, 23, 0, 0), 'average_surface_temperature': 53.89473684210526}
# {'_id': datetime.datetime(2017, 9, 24, 0, 0), 'average_surface_temperature': 53.57142857142857}
# {'_id': datetime.datetime(2017, 4, 18, 0, 0), 'average_surface_temperature': 53.36615384615384}
# {'_id': datetime.datetime(2017, 10, 10, 0, 0), 'average_surface_temperature': 53.333333333333336}
# {'_id': datetime.datetime(2017, 6, 14, 0, 0), 'average_surface_temperature': 53.25}
# {'_id': datetime.datetime(2017, 4, 5, 0, 0), 'average_surface_temperature': 53.142857142857146}
# {'_id': datetime.datetime(2017, 11, 12, 0, 0), 'average_surface_temperature': 53.0}
# {'_id': datetime.datetime(2017, 5, 10, 0, 0), 'average_surface_temperature': 52.86842105263158}
# {'_id': datetime.datetime(2017, 9, 23, 0, 0), 'average_surface_temperature': 52.73913043478261}
# {'_id': datetime.datetime(2017, 4, 12, 0, 0), 'average_surface_temperature': 52.69565217391305}
# {'_id': datetime.datetime(2017, 11, 30, 0, 0), 'average_surface_temperature': 52.41935483870968}
# {'_id': datetime.datetime(2017, 6, 4, 0, 0), 'average_surface_temperature': 52.22222222222222}
# {'_id': datetime.datetime(2017, 10, 18, 0, 0), 'average_surface_temperature': 52.166666666666664}
# {'_id': datetime.datetime(2017, 5, 17, 0, 0), 'average_surface_temperature': 52.0}
# {'_id': datetime.datetime(2017, 11, 14, 0, 0), 'average_surface_temperature': 52.0}
# {'_id': datetime.datetime(2017, 6, 7, 0, 0), 'average_surface_temperature': 51.857142857142854}
# {'_id': datetime.datetime(2017, 5, 5, 0, 0), 'average_surface_temperature': 51.70967741935484}
# {'_id': datetime.datetime(2017, 10, 17, 0, 0), 'average_surface_temperature': 51.6}
# {'_id': datetime.datetime(2017, 3, 8, 0, 0), 'average_surface_temperature': 51.5}
# {'_id': datetime.datetime(2017, 5, 12, 0, 0), 'average_surface_temperature': 51.5}
# {'_id': datetime.datetime(2017, 10, 21, 0, 0), 'average_surface_temperature': 51.25}
# {'_id': datetime.datetime(2017, 5, 23, 0, 0), 'average_surface_temperature': 51.2}
# {'_id': datetime.datetime(2017, 3, 29, 0, 0), 'average_surface_temperature': 51.0}
# {'_id': datetime.datetime(2017, 4, 17, 0, 0), 'average_surface_temperature': 50.921052631578945}
# {'_id': datetime.datetime(2017, 4, 7, 0, 0), 'average_surface_temperature': 50.69230769230769}
# {'_id': datetime.datetime(2017, 12, 8, 0, 0), 'average_surface_temperature': 50.6}
# {'_id': datetime.datetime(2017, 10, 27, 0, 0), 'average_surface_temperature': 50.4}
# {'_id': datetime.datetime(2017, 5, 7, 0, 0), 'average_surface_temperature': 50.333333333333336}
# {'_id': datetime.datetime(2017, 10, 3, 0, 0), 'average_surface_temperature': 50.0}
# {'_id': datetime.datetime(2017, 10, 20, 0, 0), 'average_surface_temperature': 50.0}
# {'_id': datetime.datetime(2017, 9, 27, 0, 0), 'average_surface_temperature': 49.714285714285715}
# {'_id': datetime.datetime(2017, 5, 26, 0, 0), 'average_surface_temperature': 49.5}
# {'_id': datetime.datetime(2017, 3, 24, 0, 0), 'average_surface_temperature': 49.0}
# {'_id': datetime.datetime(2017, 5, 14, 0, 0), 'average_surface_temperature': 49.0}
# {'_id': datetime.datetime(2017, 6, 9, 0, 0), 'average_surface_temperature': 49.0}
# {'_id': datetime.datetime(2017, 8, 13, 0, 0), 'average_surface_temperature': 49.0}
# {'_id': datetime.datetime(2017, 10, 4, 0, 0), 'average_surface_temperature': 49.0}
# {'_id': datetime.datetime(2017, 3, 31, 0, 0), 'average_surface_temperature': 48.72727272727273}
# {'_id': datetime.datetime(2017, 4, 16, 0, 0), 'average_surface_temperature': 48.72222222222222}
# {'_id': datetime.datetime(2017, 4, 25, 0, 0), 'average_surface_temperature': 48.666666666666664}
# {'_id': datetime.datetime(2017, 10, 1, 0, 0), 'average_surface_temperature': 48.25}
# {'_id': datetime.datetime(2017, 7, 29, 0, 0), 'average_surface_temperature': 48.0}
# {'_id': datetime.datetime(2017, 6, 2, 0, 0), 'average_surface_temperature': 47.72727272727273}
# {'_id': datetime.datetime(2017, 6, 3, 0, 0), 'average_surface_temperature': 47.0}
# {'_id': datetime.datetime(2017, 7, 31, 0, 0), 'average_surface_temperature': 47.0}
# {'_id': datetime.datetime(2017, 11, 13, 0, 0), 'average_surface_temperature': 47.0}
# {'_id': datetime.datetime(2017, 4, 1, 0, 0), 'average_surface_temperature': 46.714285714285715}
# {'_id': datetime.datetime(2017, 3, 9, 0, 0), 'average_surface_temperature': 46.666666666666664}
# {'_id': datetime.datetime(2017, 4, 11, 0, 0), 'average_surface_temperature': 46.291666666666664}
# {'_id': datetime.datetime(2017, 11, 11, 0, 0), 'average_surface_temperature': 46.25}
# {'_id': datetime.datetime(2017, 3, 15, 0, 0), 'average_surface_temperature': 46.0}
# {'_id': datetime.datetime(2017, 6, 22, 0, 0), 'average_surface_temperature': 46.0}
# {'_id': datetime.datetime(2017, 12, 10, 0, 0), 'average_surface_temperature': 46.0}
# {'_id': datetime.datetime(2017, 12, 21, 0, 0), 'average_surface_temperature': 46.0}
# {'_id': datetime.datetime(2017, 11, 8, 0, 0), 'average_surface_temperature': 45.5}
# {'_id': datetime.datetime(2017, 4, 2, 0, 0), 'average_surface_temperature': 45.2}
# {'_id': datetime.datetime(2017, 7, 5, 0, 0), 'average_surface_temperature': 45.0}
# {'_id': datetime.datetime(2017, 9, 22, 0, 0), 'average_surface_temperature': 45.0}
# {'_id': datetime.datetime(2017, 10, 26, 0, 0), 'average_surface_temperature': 44.6}
# {'_id': datetime.datetime(2017, 6, 30, 0, 0), 'average_surface_temperature': 44.333333333333336}
# {'_id': datetime.datetime(2017, 5, 18, 0, 0), 'average_surface_temperature': 44.142857142857146}
# {'_id': datetime.datetime(2017, 10, 9, 0, 0), 'average_surface_temperature': 44.0}
# {'_id': datetime.datetime(2017, 12, 12, 0, 0), 'average_surface_temperature': 44.0}
# {'_id': datetime.datetime(2017, 10, 6, 0, 0), 'average_surface_temperature': 44.0}
# {'_id': datetime.datetime(2017, 10, 2, 0, 0), 'average_surface_temperature': 43.57142857142857}
# {'_id': datetime.datetime(2017, 7, 2, 0, 0), 'average_surface_temperature': 43.5}
# {'_id': datetime.datetime(2017, 9, 29, 0, 0), 'average_surface_temperature': 43.0}
# {'_id': datetime.datetime(2017, 6, 16, 0, 0), 'average_surface_temperature': 42.5}
# {'_id': datetime.datetime(2017, 5, 9, 0, 0), 'average_surface_temperature': 42.46153846153846}
# {'_id': datetime.datetime(2017, 6, 18, 0, 0), 'average_surface_temperature': 42.0}
# {'_id': datetime.datetime(2017, 10, 7, 0, 0), 'average_surface_temperature': 42.0}
# {'_id': datetime.datetime(2017, 11, 28, 0, 0), 'average_surface_temperature': 42.0}
# {'_id': datetime.datetime(2017, 6, 11, 0, 0), 'average_surface_temperature': 41.5}
# {'_id': datetime.datetime(2017, 7, 14, 0, 0), 'average_surface_temperature': 41.5}
# {'_id': datetime.datetime(2017, 10, 8, 0, 0), 'average_surface_temperature': 41.0}
# {'_id': datetime.datetime(2017, 6, 13, 0, 0), 'average_surface_temperature': 41.0}
# {'_id': datetime.datetime(2017, 8, 14, 0, 0), 'average_surface_temperature': 40.8}
# {'_id': datetime.datetime(2017, 9, 21, 0, 0), 'average_surface_temperature': 40.5}
# {'_id': datetime.datetime(2017, 5, 24, 0, 0), 'average_surface_temperature': 40.333333333333336}
# {'_id': datetime.datetime(2017, 7, 4, 0, 0), 'average_surface_temperature': 40.0}
# {'_id': datetime.datetime(2017, 8, 5, 0, 0), 'average_surface_temperature': 40.0}
# {'_id': datetime.datetime(2017, 5, 16, 0, 0), 'average_surface_temperature': 39.666666666666664}
# {'_id': datetime.datetime(2017, 12, 15, 0, 0), 'average_surface_temperature': 39.0}
# {'_id': datetime.datetime(2017, 3, 13, 0, 0), 'average_surface_temperature': 38.5}
# {'_id': datetime.datetime(2017, 10, 23, 0, 0), 'average_surface_temperature': 38.0}
# {'_id': datetime.datetime(2017, 10, 16, 0, 0), 'average_surface_temperature': 36.0}
# {'_id': datetime.datetime(2017, 4, 26, 0, 0), 'average_surface_temperature': 34.0}
# {'_id': datetime.datetime(2017, 9, 26, 0, 0), 'average_surface_temperature': 33.0}
# {'_id': datetime.datetime(2017, 12, 24, 0, 0), 'average_surface_temperature': 32.0}
# {'_id': datetime.datetime(2017, 7, 1, 0, 0), 'average_surface_temperature': 30.5}
