# %%
# import statements
import uuid
from time import sleep
import datetime
from kafka import KafkaProducer
import random
import copy as copy_util


def publish_message(producer_instance, topic, key, value):
    """
    Publish message to Kafka
    :param key: Should be unique to achieve parallelism
    :param value: record to send
    """
    try:
        producer_instance.send(topic, value=value, key=key)
        print('Message published successfully. ' + value)
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))


def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['localhost:9092'],
                                  value_serializer=lambda x: x.encode('utf-8'),
                                  key_serializer=lambda x: x.encode('utf-8'),
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer


def get_record(header, data_row):
    """
    Construct the record to send as a json
    :param header: A list of field names that denote the attributes of the record.
    :param data_row: A list of data.
    :return: formatted list of records
    """
    if len(header) != len(data_row):
        raise ValueError('Data might be corrupted -> header length does not match record length')

    record = {}
    for index, attribute in enumerate(header):
        attribute = attribute.strip()
        if attribute == "latitude" or attribute == "longitude":
            record[attribute] = float(data_row[index])
        elif attribute == "surface_temperature_celcius" or attribute == "confidence":
            record[attribute] = int(data_row[index])
        else:
            raise ValueError("Failed to catch all the data fields")

    return record


def parse_file(file_location):
    """
    Get raw data from the file and parse it to a list of dictionary

    :param file_location: CSV file where the new table is derived from

    :return: A list of dictionary that represents the records
    """

    data_to_insert = []  # a list of hotspot records to insert to the database

    hotspot_AQUA_file = open(file_location)

    file_as_list = hotspot_AQUA_file.readlines()
    header = file_as_list[0].replace("\n", "").split(",")  # get a list of field name

    for index, raw_data in enumerate(file_as_list[1:]):  # loop all rows except for the header
        data_row = raw_data.replace("\n", "").split(",")
        data_to_insert.append(get_record(header, data_row))

    return data_to_insert


def start_streaming(producer, data_list, topic, interval, sender_id):
    """
    Initiate the streaming process by sending records from the given list to kafka in an arbitrary order
    :param producer: Instance of the kafka server
    :param data_list: A list of records to stream. Records are randomly selected to push to kafka
    :param topic: The topic of the record
    :param interval: The time interval of streaming data arrival
    :param sender_id: A id for the consumer to identify the producers
    """
    max_index_of_list = len(data_list)
    while True:
        index_of_list = random.randrange(0, max_index_of_list)
        selected_record = copy_util.copy(data_list[index_of_list])

        selected_record["sender_id"] = sender_id
        selected_record["created_time"] = datetime.datetime.now().strftime('%Y-%m-%dT%H:%M:%S')

        ''' push the data to kafka '''
        publish_message(producer_instance=producer, topic=topic, key=str(uuid.uuid4()), value=str(selected_record))

        sleep(interval)


print("Publishing hostpot TERRA steaming...")

# get data from the file
data_list_to_stream = parse_file("/Users/frank/Desktop/Sem3/FIT5148/Assignment/data/hotspot_TERRA_streaming.csv")

producer3 = connect_kafka_producer()  # connect to kafka as a producer

interval = random.randrange(10, 30 + 1)  # data is sent at every 10 - 30 seconds
start_streaming(producer3, data_list_to_stream, "temperature_analysis", interval, "TERRA")  # initiate the streaming process
# Out:
# Publishing hostpot TERRA steaming...
# Message published successfully. {'latitude': -37.0221, 'longitude': 141.5517, 'confidence': 76, 'surface_temperature_celcius': 50, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:38:52'}
# Message published successfully. {'latitude': -36.6995, 'longitude': 142.978, 'confidence': 95, 'surface_temperature_celcius': 76, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:39:20'}
# Message published successfully. {'latitude': -36.0829, 'longitude': 146.0621, 'confidence': 88, 'surface_temperature_celcius': 63, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:39:48'}
# Message published successfully. {'latitude': -36.6707, 'longitude': 143.8452, 'confidence': 78, 'surface_temperature_celcius': 51, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:40:16'}
# Message published successfully. {'latitude': -36.3823, 'longitude': 141.3146, 'confidence': 95, 'surface_temperature_celcius': 77, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:40:44'}
# Message published successfully. {'latitude': -36.7459, 'longitude': 141.2912, 'confidence': 71, 'surface_temperature_celcius': 55, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:41:12'}
# Message published successfully. {'latitude': -36.7754, 'longitude': 143.5261, 'confidence': 68, 'surface_temperature_celcius': 44, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:41:40'}
# Message published successfully. {'latitude': -36.6248, 'longitude': 142.2042, 'confidence': 71, 'surface_temperature_celcius': 46, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:42:08'}
# Message published successfully. {'latitude': -34.5374, 'longitude': 141.7141, 'confidence': 81, 'surface_temperature_celcius': 54, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:42:36'}
# Message published successfully. {'latitude': -36.2127, 'longitude': 141.4938, 'confidence': 78, 'surface_temperature_celcius': 51, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:43:04'}
# Message published successfully. {'latitude': -36.2637, 'longitude': 145.3649, 'confidence': 91, 'surface_temperature_celcius': 69, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:43:32'}
# Message published successfully. {'latitude': -36.4944, 'longitude': 141.8992, 'confidence': 58, 'surface_temperature_celcius': 40, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:44:00'}
# Message published successfully. {'latitude': -36.0205, 'longitude': 146.4492, 'confidence': 71, 'surface_temperature_celcius': 46, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:44:28'}
# Message published successfully. {'latitude': -36.7321, 'longitude': 143.1978, 'confidence': 54, 'surface_temperature_celcius': 46, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:44:56'}
# Message published successfully. {'latitude': -36.3728, 'longitude': 141.3641, 'confidence': 71, 'surface_temperature_celcius': 46, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:45:24'}
# Message published successfully. {'latitude': -36.3584, 'longitude': 145.9225, 'confidence': 64, 'surface_temperature_celcius': 42, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:45:52'}
# Message published successfully. {'latitude': -36.782, 'longitude': 141.8851, 'confidence': 90, 'surface_temperature_celcius': 67, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:46:20'}
# Message published successfully. {'latitude': -36.6612, 'longitude': 143.8726, 'confidence': 76, 'surface_temperature_celcius': 50, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:46:48'}
# Message published successfully. {'latitude': -36.7887, 'longitude': 143.4841, 'confidence': 51, 'surface_temperature_celcius': 38, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:47:16'}
# Message published successfully. {'latitude': -36.4373, 'longitude': 143.6328, 'confidence': 67, 'surface_temperature_celcius': 43, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:47:44'}
# Message published successfully. {'latitude': -38.0326, 'longitude': 141.5413, 'confidence': 83, 'surface_temperature_celcius': 56, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:48:12'}
# Message published successfully. {'latitude': -37.7845, 'longitude': 142.9936, 'confidence': 86, 'surface_temperature_celcius': 60, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:48:40'}
# Message published successfully. {'latitude': -36.5023, 'longitude': 143.6038, 'confidence': 85, 'surface_temperature_celcius': 66, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:49:08'}
# Message published successfully. {'latitude': -36.5069, 'longitude': 144.7323, 'confidence': 81, 'surface_temperature_celcius': 54, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:49:36'}
# Message published successfully. {'latitude': -37.9435, 'longitude': 143.5948, 'confidence': 88, 'surface_temperature_celcius': 63, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:50:04'}
# Message published successfully. {'latitude': -36.6615, 'longitude': 144.6014, 'confidence': 100, 'surface_temperature_celcius': 90, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:50:32'}
# Message published successfully. {'latitude': -37.383, 'longitude': 145.9089, 'confidence': 100, 'surface_temperature_celcius': 89, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:51:00'}
# Message published successfully. {'latitude': -36.1722, 'longitude': 142.0266, 'confidence': 73, 'surface_temperature_celcius': 47, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:51:28'}
# Message published successfully. {'latitude': -36.8403, 'longitude': 147.5354, 'confidence': 69, 'surface_temperature_celcius': 45, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:51:56'}
# Message published successfully. {'latitude': -36.0806, 'longitude': 143.7614, 'confidence': 63, 'surface_temperature_celcius': 42, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:52:24'}
# Message published successfully. {'latitude': -35.2881, 'longitude': 142.5679, 'confidence': 80, 'surface_temperature_celcius': 53, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:52:52'}
# Message published successfully. {'latitude': -37.479, 'longitude': 143.358, 'confidence': 85, 'surface_temperature_celcius': 59, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:53:20'}
# Message published successfully. {'latitude': -36.1141, 'longitude': 141.6787, 'confidence': 72, 'surface_temperature_celcius': 37, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:53:48'}
# Message published successfully. {'latitude': -38.2234, 'longitude': 143.9549, 'confidence': 56, 'surface_temperature_celcius': 39, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:54:16'}
# Message published successfully. {'latitude': -37.7212, 'longitude': 145.9754, 'confidence': 58, 'surface_temperature_celcius': 52, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:54:44'}
# Message published successfully. {'latitude': -38.0795, 'longitude': 143.2449, 'confidence': 100, 'surface_temperature_celcius': 91, 'sender_id': 'TERRA', 'created_time': '2019-05-24T10:55:12'}
